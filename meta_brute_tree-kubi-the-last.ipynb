# %% [markdown]
# <a href="https://colab.research.google.com/github/yakaralar/IE492/blob/master/meta_brute_tree-kubi-the-last.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import glob
import shutil
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
os.listdir("drive/My Drive/colab_datas/IE 492")
# Out:
# ['Comparison of methods.pdf',
#  '1-s2.0-S1364032114000914-main.pdf',
#  '1-s2.0-S0360544209002539-main.pdf',
#  '1-s2.0-S1876610211043116-main.pdf',
#  '1-s2.0-S0305048311001423-main.pdf',
#  'weather_turkey_processed.zip',
#  'Meta_L_makaleler',
#  'all_data.feather',
#  'UECM-15012015-20022020.csv',
#  'RealTimeConsumption-01122014-09032020.csv',
#  'updated_support-date_based_information.r',
#  'ozel_gunler',
#  'RealTimeConsumption_unholidayized.csv',
#  'RealTimeConsumption_unhol_decomposed.csv',
#  'RealTimeConsumption_holiday.csv',
#  'kubi_preds',
#  'arima_preds.csv',
#  'arima_preds_datetime.csv',
#  'gpw_v4_admin_unit_center_points_population_estimates_rev11_tur.csv',
#  'gpw-v4-country-level-summary-rev11.xlsx',
#  'gpw-v4-documentation-rev11.pdf',
#  'kubi_weather_data_20151231-2020-04-02.csv',
#  'kubi_temp_humid_wind_data_20151231-2020-04-02.csv',
#  'lasso_coeffs_new.csv']

# %%
shutil.copy("drive/My Drive/colab_datas/IE 492/RealTimeConsumption_unholidayized.csv","./")
shutil.copy("drive/My Drive/colab_datas/IE 492/RealTimeConsumption-01122014-09032020.csv","./")
shutil.copy("drive/My Drive/colab_datas/IE 492/RealTimeConsumption_holiday.csv","./")
shutil.copy("drive/My Drive/colab_datas/IE 492/kubi_temp_humid_wind_data_20151231-2020-04-02.csv","./")
# Out:
# './kubi_temp_humid_wind_data_20151231-2020-04-02.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling
# %matplotlib inline
from tqdm.notebook import tqdm
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # eval func

# %%
# !pip install graphviz
# !pip install sklearn --upgrade
from sklearn.metrics import mean_squared_error,mean_squared_log_error,mean_absolute_error
from sklearn.tree import DecisionTreeRegressor,plot_tree

def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

eval_df=[]
def eval_function(name_,y_true, y_pred,valid_df):
    """
    name_:kullanılan modelin ismi
    y_true:actual values
    y_pred:predicted values
    valid_df:modele verdiginiz sekliyle validation dataframe'i ve yanına datetime'ı
    """
    ap="drive/My Drive/colab_datas/IE 492/kubi_preds/eval_plots/"+name_
    if not os.path.exists(ap):
        os.mkdir(ap)
    rmse_=np.sqrt(mean_squared_error(y_true,y_pred))
    rmsle_=np.sqrt(mean_squared_log_error(y_true,y_pred))
    mae_=mean_absolute_error(y_true,y_pred)
    mape_=mean_absolute_percentage_error(y_true, y_pred)
    mapes_each_period=[mean_absolute_percentage_error(y_true[i],y_pred[i]) for i in range(len(y_true))]
    mapes_each_period=pd.DataFrame(mapes_each_period,columns=["mapes"])
    mapes_each_period["Datetime"]=valid_df["Datetime"].iloc[-len(mapes_each_period):]
    print("RMSE: ",rmse_)
    print("RMSLE: ",rmsle_)
    print("MAE: ",mae_)
    print("MAPE: ",mape_)
    fig=plt.figure(figsize=(16,10))
    sns.scatterplot(x=y_pred,y=y_true)
    fig.savefig("drive/My Drive/colab_datas/IE 492/kubi_preds/eval_plots/"+name_+"/actual_vs_predicted.png")
    plt.pause(0.01)
    fig=plt.figure(figsize=(16,10))
    sns.residplot(y_true,y_pred)
    plt.pause(0.01)
    fig.savefig("drive/My Drive/colab_datas/IE 492/kubi_preds/eval_plots/"+name_+"/residplot.png")
    nchunks=6 # plot count
    fig,ax=plt.subplots(nrows=32,figsize=(32,125))
    valid_copy=valid_df.reset_index(drop=True).copy()

    for i,datetime_ in enumerate(np.array_split(valid_copy["Datetime"],32)):
        sns.lineplot(y=y_true[datetime_.index.tolist()],x=datetime_,color="green",ax=ax[i])
        sns.lineplot(y=y_pred[datetime_.index.tolist()],x=datetime_,color="red",ax=ax[i])
    fig.savefig("drive/My Drive/colab_datas/IE 492/kubi_preds/eval_plots/"+name_+"/lineplot_pred_act_{}.png".format(i))

    fig,ax=plt.subplots(nrows=nchunks,figsize=(32,25))
    for i,datetime_ in enumerate(np.array_split(mapes_each_period,nchunks)):
        sns.lineplot(y="mapes",x="Datetime",data=datetime_,ax=ax[i])
    fig.savefig("drive/My Drive/colab_datas/IE 492/kubi_preds/eval_plots/"+name_+"/lineplot_errors.png")

    # plt.pause(0.01)
    # res_model=DecisionTreeRegressor(max_depth=4)
    # _, ax = plt.subplots(figsize=(60, 60))  # whatever size you want
    # fig=res_model.fit(valid_df.drop(columns=["Datetime"]),y_true-y_pred)
    # plot_tree(fig,ax=ax,feature_names=valid_df.drop(columns=["Datetime"]).columns,fontsize=16)
    # plt.pause(0.01)
    # ## saatlik mape tanımla
    return name_, rmse_,rmsle_,mae_,mape_
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (0.10.1)
# Requirement already up-to-date: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (0.15.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.18.4)

# %% [markdown]
# # Consumption df

# %%
# # bruuuuuuuh
# cons_holiday_binary=pd.read_csv("RealTimeConsumption_holiday.csv",encoding='latin-1')
# cons_holiday_binary["Datetime"]=cons_holiday_binary["Date"]+" "+cons_holiday_binary["Hour"]
# cons_holiday_binary["Datetime"]=pd.to_datetime(cons_holiday_binary["Datetime"],format="%d.%m.%Y %H:%M")
# cons_holiday_binary.head()

# %%
# catboostu 1 aylık yap

# %%
preds_paths=glob.glob("drive/My Drive/colab_datas/IE 492/kubi_preds/*.csv")
preds_paths
# Out:
# ['drive/My Drive/colab_datas/IE 492/kubi_preds/LR_2.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/naive_2.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/LR_2_7_w_dates.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/naive_7.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/LR_2_7.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/LR_7.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/ygur_rima_preds_datetime.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/Cat1_48hours.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/Cat2_categorical_48hours.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/Cat1_24hours.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/Cat2_categorical_24hours.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/Keras_Basic_dense_24.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/Keras_Basic_dense_48.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/HW_preds_48hours.csv',
#  'drive/My Drive/colab_datas/IE 492/kubi_preds/HW_preds_24hours.csv']

# %%
#a=pd.read_csv("drive/My Drive/colab_datas/IE 492/kubi_preds/ygur_rima_preds_datetime.csv")
#a["Datetime"]=pd.to_datetime(a["Datetime"],format="%d/%m/%Y %H:%M")
#a=a.iloc[:,:-1]
#a.columns=["Datetime","Arima"]
#a.to_csv("drive/My Drive/colab_datas/IE 492/kubi_preds/ygur_rima_preds_datetime.csv",index=False)

# %%
#path_="drive/My Drive/colab_datas/IE 492/kubi_preds/erdem_HW_preds_new.csv"
#a=pd.read_csv(path_)
#a["Datetime"]=pd.to_datetime(a["Datetime"])
#a.loc[a["Datetime"]>=pd.to_datetime("2019-02-01 00:00:00")][["Datetime","HW_unhol_reg"]].to_csv(path_,index=False)

# %%
pred_dfs=[]
for i,path_ in enumerate(preds_paths):
    df=pd.read_csv(path_)
    if "HW" in path_:
        df=df.loc[df["Datetime"].between('2019-02-01','2020-03-05')].reset_index(drop=True)
    elif "rima" in path_:
        df["Datetime"]=pd.date_range('2019-02-01','2020-03-04',freq="H")[:-1]
    df.columns=["Datetime_"+str(i),path_.split("/")[-1].strip(".csv")]
    pred_dfs.append(df)
preds=pd.concat(pred_dfs,axis=1)
preds
# Out:
#                Datetime_0          LR_2  ...          Datetime_14  HW_preds_24hour
# 0     2019-02-01 00:00:00  31744.801869  ...  2019-02-01 00:00:00     32245.453202
# 1     2019-02-01 01:00:00  30353.806407  ...  2019-02-01 01:00:00     30317.336597
# 2     2019-02-01 02:00:00  29429.213104  ...  2019-02-01 02:00:00     28718.710641
# 3     2019-02-01 03:00:00  28904.205359  ...  2019-02-01 03:00:00     27928.743341
# 4     2019-02-01 04:00:00  28714.921348  ...  2019-02-01 04:00:00     27679.824148
# ...                   ...           ...  ...                  ...              ...
# 9523  2020-03-03 19:00:00  34433.450000  ...  2020-03-03 19:00:00     39194.639686
# 9524  2020-03-03 20:00:00  34324.041524  ...  2020-03-03 20:00:00     38307.274402
# 9525  2020-03-03 21:00:00  33821.654912  ...  2020-03-03 21:00:00     37190.286189
# 9526  2020-03-03 22:00:00  33102.945835  ...  2020-03-03 22:00:00     35839.197807
# 9527  2020-03-03 23:00:00  32035.951504  ...  2020-03-03 23:00:00     34227.293006
#
# [9528 rows x 30 columns]

# %%
preds=preds[["Datetime_0"]+[i for i in preds.columns if not i.startswith("Datetime")]].rename(columns={"Datetime_0":"Datetime"})
preds
# Out:
#                  Datetime          LR_2  ...  HW_preds_48hour  HW_preds_24hour
# 0     2019-02-01 00:00:00  31744.801869  ...     31161.780355     32245.453202
# 1     2019-02-01 01:00:00  30353.806407  ...     29447.620186     30317.336597
# 2     2019-02-01 02:00:00  29429.213104  ...     28451.395711     28718.710641
# 3     2019-02-01 03:00:00  28904.205359  ...     27704.391751     27928.743341
# 4     2019-02-01 04:00:00  28714.921348  ...     27392.449683     27679.824148
# ...                   ...           ...  ...              ...              ...
# 9523  2020-03-03 19:00:00  34433.450000  ...     35196.746675     39194.639686
# 9524  2020-03-03 20:00:00  34324.041524  ...     34905.761724     38307.274402
# 9525  2020-03-03 21:00:00  33821.654912  ...     34102.138172     37190.286189
# 9526  2020-03-03 22:00:00  33102.945835  ...     33085.861894     35839.197807
# 9527  2020-03-03 23:00:00  32035.951504  ...     31793.396419     34227.293006
#
# [9528 rows x 16 columns]

# %%
preds.isna().sum()
# Out:
# Datetime                    0
# LR_2                        0
# naive_2                     0
# LR_2_7_w_date               0
# naive_7                     0
# LR_2_7                      0
# LR_7                        0
# ygur_rima_preds_datetime    0
# Cat1_48hour                 0
# Cat2_categorical_48hour     0
# Cat1_24hour                 0
# Cat2_categorical_24hour     0
# Keras_Basic_dense_24        0
# Keras_Basic_dense_48        0
# HW_preds_48hour             0
# HW_preds_24hour             0
# dtype: int64

# %%
# bruuuuuuuh
cons_holiday_binary=pd.read_csv("RealTimeConsumption_holiday.csv",encoding='latin-1')
cons_holiday_binary["Datetime"]=cons_holiday_binary["Date"]+" "+cons_holiday_binary["Hour"]
cons_holiday_binary["Datetime"]=pd.to_datetime(cons_holiday_binary["Datetime"],format="%d.%m.%Y %H:%M")
cons_holiday_binary.head()
# Out:
#          Date   Hour  ...  is_yilbasioncesi is_zaferbayrami
# 0  31.12.2015  00:00  ...                 1               0
# 1  31.12.2015  01:00  ...                 1               0
# 2  31.12.2015  02:00  ...                 1               0
# 3  31.12.2015  03:00  ...                 1               0
# 4  31.12.2015  04:00  ...                 1               0
#
# [5 rows x 43 columns]

# %%
preds["reel"]=cons_holiday_binary.loc[cons_holiday_binary["Datetime"]>=pd.to_datetime("2019-02-01 00:00:00")][["Consumption"]].values
preds.Datetime=pd.to_datetime(preds.Datetime)
preds
# Out:
#                 Datetime          LR_2  ...  HW_preds_24hour      reel
# 0    2019-02-01 00:00:00  31744.801869  ...     32245.453202  31878.29
# 1    2019-02-01 01:00:00  30353.806407  ...     30317.336597  30064.08
# 2    2019-02-01 02:00:00  29429.213104  ...     28718.710641  28813.77
# 3    2019-02-01 03:00:00  28904.205359  ...     27928.743341  27865.76
# 4    2019-02-01 04:00:00  28714.921348  ...     27679.824148  27554.48
# ...                  ...           ...  ...              ...       ...
# 9523 2020-03-03 19:00:00  34433.450000  ...     39194.639686  37936.79
# 9524 2020-03-03 20:00:00  34324.041524  ...     38307.274402  37553.37
# 9525 2020-03-03 21:00:00  33821.654912  ...     37190.286189  36581.73
# 9526 2020-03-03 22:00:00  33102.945835  ...     35839.197807  35434.36
# 9527 2020-03-03 23:00:00  32035.951504  ...     34227.293006  33827.00
#
# [9528 rows x 17 columns]

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mapes={}
calc_mapes=preds.set_index("Datetime")
for model_name in calc_mapes.columns[:-1]:
    y_true,y_pred=calc_mapes[["reel",model_name]].values.T
    mape_=mean_absolute_percentage_error(y_true,y_pred)
    mapes[model_name]=mape_
pd.DataFrame([list(mapes.keys()),list(mapes.values())]).T.sort_values(1)
# Out:
#                            0        1
# 9                Cat1_24hour  2.61997
# 11      Keras_Basic_dense_24   2.8726
# 10   Cat2_categorical_24hour  2.94813
# 7                Cat1_48hour  2.99118
# 8    Cat2_categorical_48hour  3.24907
# 6   ygur_rima_preds_datetime  3.46533
# 12      Keras_Basic_dense_48  3.68307
# 2              LR_2_7_w_date  4.05324
# 4                     LR_2_7  4.98923
# 3                    naive_7  5.20805
# 5                       LR_7  5.22779
# 14           HW_preds_24hour  6.15247
# 0                       LR_2  7.85569
# 13           HW_preds_48hour  7.95579
# 1                    naive_2  8.15892

# %%
## 5 iq move düzelt bunu
best_models=[]
for i,row in preds.iterrows():
    best_mape=999999
    best_model=""
    for col in preds.columns.difference(["Datetime","reel"]):
        mape_=mean_absolute_percentage_error(row["reel"],row[col])
        if best_mape>mape_:
            best_mape=mape_
            best_model=col
    best_models.append(best_model)
preds["best_model"]=best_models
len(preds)+1
# Out:
# 9529

# %%
mapes["best_case"]=preds.loc[preds["best_model"]!="unknown"].apply(lambda x: mean_absolute_percentage_error(x["reel"],x[x["best_model"]]),axis=1).mean()

# %%
mapes
# Out:
# {'Cat1_24hour': 2.6199679513147114,
#  'Cat1_48hour': 2.991182739400095,
#  'Cat2_categorical_24hour': 2.948131281186649,
#  'Cat2_categorical_48hour': 3.2490686862665186,
#  'HW_preds_24hour': 6.152474388551419,
#  'HW_preds_48hour': 7.955785251367757,
#  'Keras_Basic_dense_24': 2.8725964452793478,
#  'Keras_Basic_dense_48': 3.683070359734644,
#  'LR_2': 7.855694573000102,
#  'LR_2_7': 4.989226864853979,
#  'LR_2_7_w_date': 4.053236198257791,
#  'LR_7': 5.22779264475642,
#  'best_case': 0.6872404772042718,
#  'naive_2': 8.15891679451568,
#  'naive_7': 5.208054715113833,
#  'ygur_rima_preds_datetime': 3.4653294353157422}

# %%
def brute_meta(n,buffer):
    shift_timespan=n*24
    chosen_models=["unknown"]*(shift_timespan+buffer)
    print("meta brute with n = {}, buffer = {}".format(n,buffer))
    for i in tqdm(range(shift_timespan,len(preds))):
        ## buraya prob koyacaggız
        chosen_models.append(preds["best_model"].iloc[i-shift_timespan:i].value_counts().index[0])
    preds["chosen"]=chosen_models[:len(chosen_models)-buffer]
    mapes_brute=preds.loc[preds["chosen"]!="unknown"].apply(lambda x: mean_absolute_percentage_error(x["reel"],x[x["chosen"]]),axis=1)
    mapes["window_{}_days_{}_buffer".format(n,buffer)]=mapes_brute.mean()
    print(mapes_brute.mean())

# %%
combins=np.concatenate([[(j,i) for i in [0,24,48]] for j in [5,7,14,28,30]])
for n,buffer in combins:
    brute_meta(n,buffer)
# Out:
# meta brute with n = 5, buffer = 0
# HBox(children=(FloatProgress(value=0.0, max=9408.0), HTML(value='')))
# 3.408850416203426
# meta brute with n = 5, buffer = 24
# HBox(children=(FloatProgress(value=0.0, max=9408.0), HTML(value='')))
# 3.95668808178304
# meta brute with n = 5, buffer = 48
# HBox(children=(FloatProgress(value=0.0, max=9408.0), HTML(value='')))
# 3.9485640739674728
# meta brute with n = 7, buffer = 0
# HBox(children=(FloatProgress(value=0.0, max=9360.0), HTML(value='')))
# 3.033289980766917
# meta brute with n = 7, buffer = 24
# HBox(children=(FloatProgress(value=0.0, max=9360.0), HTML(value='')))
# 3.3503209683242865
# meta brute with n = 7, buffer = 48
# HBox(children=(FloatProgress(value=0.0, max=9360.0), HTML(value='')))
# 3.372307076487245
# meta brute with n = 14, buffer = 0
# HBox(children=(FloatProgress(value=0.0, max=9192.0), HTML(value='')))
# 2.939732944448012
# meta brute with n = 14, buffer = 24
# HBox(children=(FloatProgress(value=0.0, max=9192.0), HTML(value='')))
# 2.997888910308739
# meta brute with n = 14, buffer = 48
# HBox(children=(FloatProgress(value=0.0, max=9192.0), HTML(value='')))
# 2.9582858089665347
# meta brute with n = 28, buffer = 0
# HBox(children=(FloatProgress(value=0.0, max=8856.0), HTML(value='')))
# 3.0181765251982773
# meta brute with n = 28, buffer = 24
# HBox(children=(FloatProgress(value=0.0, max=8856.0), HTML(value='')))
# 3.0795944880650645
# meta brute with n = 28, buffer = 48
# HBox(children=(FloatProgress(value=0.0, max=8856.0), HTML(value='')))
# 3.056409290568626
# meta brute with n = 30, buffer = 0
# HBox(children=(FloatProgress(value=0.0, max=8808.0), HTML(value='')))
# 3.026801674473698
# meta brute with n = 30, buffer = 24
# HBox(children=(FloatProgress(value=0.0, max=8808.0), HTML(value='')))
# 3.08247866415245
# meta brute with n = 30, buffer = 48
# HBox(children=(FloatProgress(value=0.0, max=8808.0), HTML(value='')))
# 3.0582706261034223

# %%
# shift_timespan=7*24
# chosen_models=["unknown"]*(shift_timespan)
# for i in tqdm(range(shift_timespan,len(preds))):
#     ## buraya prob koyacaggız
#     chosen_models.append(preds["best_model"].iloc[i-shift_timespan:i].value_counts().index[0])
# preds["chosen"]=chosen_models
# mapes_brute=preds.loc[preds["chosen"]!="unknown"].apply(lambda x: mean_absolute_percentage_error(x["reel"],x[x["chosen"]]),axis=1)
# mapes["window_7_days"]=mapes_brute.mean()
# mapes_brute.mean()
# 
# shift_timespan=5*24
# chosen_models=["unknown"]*(shift_timespan+48)
# for i in tqdm(range(shift_timespan,len(preds))):
#     ## buraya prob koyacaggız
#     chosen_models.append(preds["best_model"].iloc[i-shift_timespan:i].value_counts().index[0])
# preds["chosen_5"]=chosen_models[:-48]
# mapes_brute=preds.loc[preds["chosen_5"]!="unknown"].apply(lambda x: mean_absolute_percentage_error(x["reel"],x[x["chosen_5"]]),axis=1)
# mapes["window_5_days"]=mapes_brute.mean()
# 
# shift_timespan=14*24
# chosen_models=["unknown"]*(shift_timespan+48)
# for i in tqdm(range(shift_timespan,len(preds))):
#     chosen_models.append(preds["best_model"].iloc[i-shift_timespan:i].value_counts().index[0])
# preds["chosen_14"]=chosen_models[:-48]
# mapes_brute=preds.loc[preds["chosen_14"]!="unknown"].apply(lambda x: mean_absolute_percentage_error(x["reel"],x[x["chosen_14"]]),axis=1)
# mapes["window_14_days"]=mapes_brute.mean()
# 
# shift_timespan=30*24
# chosen_models=["unknown"]*(shift_timespan+48)
# for i in tqdm(range(shift_timespan,len(preds))):
#     chosen_models.append(preds["best_model"].iloc[i-shift_timespan:i].value_counts().index[0])
# preds["chosen_30"]=chosen_models[:-48]
# mapes_brute=preds.loc[preds["chosen_30"]!="unknown"].apply(lambda x: mean_absolute_percentage_error(x["reel"],x[x["chosen_30"]]),axis=1)
# mapes["window_30_days"]=mapes_brute.mean()

# %%
mapes
# Out:
# {'Cat1_24hour': 2.6199679513147114,
#  'Cat1_48hour': 2.991182739400095,
#  'Cat2_categorical_24hour': 2.948131281186649,
#  'Cat2_categorical_48hour': 3.2490686862665186,
#  'HW_preds_24hour': 6.152474388551419,
#  'HW_preds_48hour': 7.955785251367757,
#  'Keras_Basic_dense_24': 2.8725964452793478,
#  'Keras_Basic_dense_48': 3.683070359734644,
#  'LR_2': 7.855694573000102,
#  'LR_2_7': 4.989226864853979,
#  'LR_2_7_w_date': 4.053236198257791,
#  'LR_7': 5.22779264475642,
#  'best_case': 0.6872404772042718,
#  'naive_2': 8.15891679451568,
#  'naive_7': 5.208054715113833,
#  'window_14_days_0_buffer': 2.939732944448012,
#  'window_14_days_24_buffer': 2.997888910308739,
#  'window_14_days_48_buffer': 2.9582858089665347,
#  'window_28_days_0_buffer': 3.0181765251982773,
#  'window_28_days_24_buffer': 3.0795944880650645,
#  'window_28_days_48_buffer': 3.056409290568626,
#  'window_30_days_0_buffer': 3.026801674473698,
#  'window_30_days_24_buffer': 3.08247866415245,
#  'window_30_days_48_buffer': 3.0582706261034223,
#  'window_5_days_0_buffer': 3.408850416203426,
#  'window_5_days_24_buffer': 3.95668808178304,
#  'window_5_days_48_buffer': 3.9485640739674728,
#  'window_7_days_0_buffer': 3.033289980766917,
#  'window_7_days_24_buffer': 3.3503209683242865,
#  'window_7_days_48_buffer': 3.372307076487245,
#  'ygur_rima_preds_datetime': 3.4653294353157422}

# %%
nisan_24=preds.loc[preds["Datetime"].between(pd.to_datetime("2019-04-24 00:00:00"),pd.to_datetime("2019-04-25 00:00:00"))]
day_by_day_sort={}
for i,row in nisan_24.iterrows():
    mapes_a={}
    for col in nisan_24.columns[1:11]:
        mape_=mean_absolute_percentage_error(row["reel"],row[col])
        mapes_a[col]=mape_
    day_by_day_sort[row["Datetime"]]=mapes_a
day_by_day_sort
# Out:
# {Timestamp('2019-04-24 00:00:00'): {'Cat1_24hour': 3.9682948505904756,
#   'Cat1_48hour': 3.2550492638705992,
#   'Cat2_categorical_48hour': 4.0141117858170565,
#   'LR_2': 1.8654968712021158,
#   'LR_2_7': 4.078852493495687,
#   'LR_2_7_w_date': 3.7699078135235085,
#   'LR_7': 6.957455676398823,
#   'naive_2': 1.3105580265177919,
#   'naive_7': 6.193579003332738,
#   'ygur_rima_preds_datetime': 6.636509101465669},
#  Timestamp('2019-04-24 01:00:00'): {'Cat1_24hour': 4.498841079847919,
#   'Cat1_48hour': 4.149418695961482,
#   'Cat2_categorical_48hour': 3.9536312716998854,
#   'LR_2': 2.948258726195324,
#   'LR_2_7': 4.214070795705579,
#   'LR_2_7_w_date': 4.332855355359548,
#   'LR_7': 7.993531180302443,
#   'naive_2': 2.02019839323456,
#   'naive_7': 6.291836117680087,
#   'ygur_rima_preds_datetime': 6.5047205108557495},
#  Timestamp('2019-04-24 02:00:00'): {'Cat1_24hour': 3.358198148889057,
#   'Cat1_48hour': 3.224480103978185,
#   'Cat2_categorical_48hour': 3.527110735605522,
#   'LR_2': 3.502619439506481,
#   'LR_2_7': 3.677257964248374,
#   'LR_2_7_w_date': 4.087481895069938,
#   'LR_7': 7.870592444446409,
#   'naive_2': 2.6101126799948258,
#   'naive_7': 5.453981739335863,
#   'ygur_rima_preds_datetime': 5.704276521595308},
#  Timestamp('2019-04-24 03:00:00'): {'Cat1_24hour': 1.8502278221433042,
#   'Cat1_48hour': 2.410792701530515,
#   'Cat2_categorical_48hour': 3.5445055807369,
#   'LR_2': 4.001246537879864,
#   'LR_2_7': 3.7619579394732234,
#   'LR_2_7_w_date': 4.427110014332976,
#   'LR_7': 8.305797772798984,
#   'naive_2': 2.831019410139902,
#   'naive_7': 5.504671591067904,
#   'ygur_rima_preds_datetime': 5.353589430982065},
#  Timestamp('2019-04-24 04:00:00'): {'Cat1_24hour': 1.2033436229421555,
#   'Cat1_48hour': 1.9257992582871288,
#   'Cat2_categorical_48hour': 3.0179520436952036,
#   'LR_2': 4.198248640529659,
#   'LR_2_7': 3.3376557523890904,
#   'LR_2_7_w_date': 4.095985938252773,
#   'LR_7': 7.705234576730109,
#   'naive_2': 2.6779513114260487,
#   'naive_7': 4.738077435862181,
#   'ygur_rima_preds_datetime': 5.252979705942553},
#  Timestamp('2019-04-24 05:00:00'): {'Cat1_24hour': 2.0729564377110834,
#   'Cat1_48hour': 1.9895880230785927,
#   'Cat2_categorical_48hour': 4.3780745065269455,
#   'LR_2': 3.6562394058219523,
#   'LR_2_7': 3.6286312965403154,
#   'LR_2_7_w_date': 4.500940611090547,
#   'LR_7': 8.03057803710513,
#   'naive_2': 2.8631470021989305,
#   'naive_7': 5.404271512688378,
#   'ygur_rima_preds_datetime': 5.509884954474824},
#  Timestamp('2019-04-24 06:00:00'): {'Cat1_24hour': 3.7507804060594667,
#   'Cat1_48hour': 3.900458458960957,
#   'Cat2_categorical_48hour': 4.7702315018972685,
#   'LR_2': 5.078179642605009,
#   'LR_2_7': 4.705915555744769,
#   'LR_2_7_w_date': 5.6582180434746405,
#   'LR_7': 8.945092739668684,
#   'naive_2': 1.3698754624248002,
#   'naive_7': 6.2642135276053885,
#   'ygur_rima_preds_datetime': 7.0838813769183275},
#  Timestamp('2019-04-24 07:00:00'): {'Cat1_24hour': 2.1244738139199666,
#   'Cat1_48hour': 2.251857494239286,
#   'Cat2_categorical_48hour': 2.4212320034820025,
#   'LR_2': 2.5346198413557346,
#   'LR_2_7': 3.619880293081109,
#   'LR_2_7_w_date': 4.337853810398806,
#   'LR_7': 6.95919600901474,
#   'naive_2': 1.8728720770997433,
#   'naive_7': 5.436967611288892,
#   'ygur_rima_preds_datetime': 5.28811277739963},
#  Timestamp('2019-04-24 08:00:00'): {'Cat1_24hour': 0.9642081193757205,
#   'Cat1_48hour': 0.9533003101344988,
#   'Cat2_categorical_48hour': 0.7424969588456971,
#   'LR_2': 1.5394220351773336,
#   'LR_2_7': 1.9254651588051015,
#   'LR_2_7_w_date': 1.9846042261454546,
#   'LR_7': 3.3158282728192567,
#   'naive_2': 1.9076873382060096,
#   'naive_7': 3.9659430789882175,
#   'ygur_rima_preds_datetime': 3.9052300350594815},
#  Timestamp('2019-04-24 09:00:00'): {'Cat1_24hour': 2.7275687538762834,
#   'Cat1_48hour': 0.7721069268422436,
#   'Cat2_categorical_48hour': 0.5103206566513978,
#   'LR_2': 2.707178039422696,
#   'LR_2_7': 1.5079933010510906,
#   'LR_2_7_w_date': 1.3673307585840448,
#   'LR_7': 2.1348382237815717,
#   'naive_2': 1.58209603390312,
#   'naive_7': 3.557023477731485,
#   'ygur_rima_preds_datetime': 2.655520431783367},
#  Timestamp('2019-04-24 10:00:00'): {'Cat1_24hour': 0.5432642143102961,
#   'Cat1_48hour': 2.37188573719354,
#   'Cat2_categorical_48hour': 1.1094223759491957,
#   'LR_2': 1.8869578638173714,
#   'LR_2_7': 2.287116650913364,
#   'LR_2_7_w_date': 2.197003104527242,
#   'LR_7': 2.7758211150291334,
#   'naive_2': 0.5783178749331183,
#   'naive_7': 4.2607179461107085,
#   'ygur_rima_preds_datetime': 2.8936606885969},
#  Timestamp('2019-04-24 11:00:00'): {'Cat1_24hour': 0.36264398710818235,
#   'Cat1_48hour': 2.192222375732679,
#   'Cat2_categorical_48hour': 1.2832353468181483,
#   'LR_2': 1.4926733010776743,
#   'LR_2_7': 2.683595108484473,
#   'LR_2_7_w_date': 2.6720241369136417,
#   'LR_7': 3.1145834003663433,
#   'naive_2': 0.09787595011712057,
#   'naive_7': 4.634048679325618,
#   'ygur_rima_preds_datetime': 2.8535623026857713},
#  Timestamp('2019-04-24 12:00:00'): {'Cat1_24hour': 2.3951366965952126,
#   'Cat1_48hour': 4.497111431436777,
#   'Cat2_categorical_48hour': 3.062618899555742,
#   'LR_2': 1.7327015575613638,
#   'LR_2_7': 4.392555433509935,
#   'LR_2_7_w_date': 4.617413520802764,
#   'LR_7': 4.979127290424169,
#   'naive_2': 2.155879880844766,
#   'naive_7': 5.7496182914785,
#   'ygur_rima_preds_datetime': 4.77184272962604},
#  Timestamp('2019-04-24 13:00:00'): {'Cat1_24hour': 2.9596616351209146,
#   'Cat1_48hour': 2.867894077619607,
#   'Cat2_categorical_48hour': 3.2116441146042245,
#   'LR_2': 1.7715059912441888,
#   'LR_2_7': 5.1932197933618625,
#   'LR_2_7_w_date': 5.53183788367942,
#   'LR_7': 5.901607113576344,
#   'naive_2': 2.3876483190381586,
#   'naive_7': 6.930766128896447,
#   'ygur_rima_preds_datetime': 6.709274385283355},
#  Timestamp('2019-04-24 14:00:00'): {'Cat1_24hour': 4.701614464949092,
#   'Cat1_48hour': 4.131023913966744,
#   'Cat2_categorical_48hour': 3.1087758191883785,
#   'LR_2': 1.0577407273571582,
#   'LR_2_7': 4.6790292224768235,
#   'LR_2_7_w_date': 5.0147428660187465,
#   'LR_7': 5.136023735973446,
#   'naive_2': 2.1424026359174917,
#   'naive_7': 6.398960794085736,
#   'ygur_rima_preds_datetime': 4.661893294279142},
#  Timestamp('2019-04-24 15:00:00'): {'Cat1_24hour': 4.348785606241959,
#   'Cat1_48hour': 3.6178870093048334,
#   'Cat2_categorical_48hour': 2.1600266657759626,
#   'LR_2': 0.3285162061157635,
#   'LR_2_7': 4.101756261757064,
#   'LR_2_7_w_date': 4.595833990564558,
#   'LR_7': 4.730590826956989,
#   'naive_2': 1.2341235182723322,
#   'naive_7': 5.959075786721573,
#   'ygur_rima_preds_datetime': 3.405454786454979},
#  Timestamp('2019-04-24 16:00:00'): {'Cat1_24hour': 2.7353097393741628,
#   'Cat1_48hour': 1.914476613359855,
#   'Cat2_categorical_48hour': 1.0354289235759022,
#   'LR_2': 0.2694001554930744,
#   'LR_2_7': 3.387291694801495,
#   'LR_2_7_w_date': 3.904462153949361,
#   'LR_7': 3.802549417859649,
#   'naive_2': 0.8943065678783345,
#   'naive_7': 5.105736517011607,
#   'ygur_rima_preds_datetime': 3.353256760270081},
#  Timestamp('2019-04-24 17:00:00'): {'Cat1_24hour': 3.1154572327239043,
#   'Cat1_48hour': 2.776220579122948,
#   'Cat2_categorical_48hour': 1.836613248882513,
#   'LR_2': 0.3601518023943517,
#   'LR_2_7': 3.6815530489413377,
#   'LR_2_7_w_date': 4.212119858999907,
#   'LR_7': 3.8138987538849265,
#   'naive_2': 1.7770831097804713,
#   'naive_7': 5.137156313270381,
#   'ygur_rima_preds_datetime': 4.10688101602861},
#  Timestamp('2019-04-24 18:00:00'): {'Cat1_24hour': 2.7974363694230515,
#   'Cat1_48hour': 3.097413241814393,
#   'Cat2_categorical_48hour': 1.3008389211120817,
#   'LR_2': 0.45606252051242835,
#   'LR_2_7': 3.481726878351689,
#   'LR_2_7_w_date': 4.127306191565541,
#   'LR_7': 3.60241199514866,
#   'naive_2': 1.7455271016127902,
#   'naive_7': 4.804376140236966,
#   'ygur_rima_preds_datetime': 3.436620168053792},
#  Timestamp('2019-04-24 19:00:00'): {'Cat1_24hour': 0.7825675524797883,
#   'Cat1_48hour': 1.8571404298594913,
#   'Cat2_categorical_48hour': 0.20827759749708205,
#   'LR_2': 0.5148371118313597,
#   'LR_2_7': 2.561947670835485,
#   'LR_2_7_w_date': 3.0503214291382696,
#   'LR_7': 2.0680970404822205,
#   'naive_2': 1.7062126570921126,
#   'naive_7': 3.652098271327817,
#   'ygur_rima_preds_datetime': 3.3237727413552847},
#  Timestamp('2019-04-24 20:00:00'): {'Cat1_24hour': 0.8323270258848128,
#   'Cat1_48hour': 0.7853097439263438,
#   'Cat2_categorical_48hour': 0.958583725823541,
#   'LR_2': 2.135411904353272,
#   'LR_2_7': 1.2750385709806236,
#   'LR_2_7_w_date': 1.705271963753786,
#   'LR_7': 0.48623574370619677,
#   'naive_2': 0.6841098136798913,
#   'naive_7': 2.3879133730183177,
#   'ygur_rima_preds_datetime': 1.8028836367593215},
#  Timestamp('2019-04-24 21:00:00'): {'Cat1_24hour': 0.8207741310241995,
#   'Cat1_48hour': 0.6938673333599357,
#   'Cat2_categorical_48hour': 0.25544894010138264,
#   'LR_2': 1.9357901159720703,
#   'LR_2_7': 1.1149118249503982,
#   'LR_2_7_w_date': 1.7851488430268403,
#   'LR_7': 0.6182580704682268,
#   'naive_2': 0.27681280099180555,
#   'naive_7': 2.1931378499674685,
#   'ygur_rima_preds_datetime': 0.9980845171806837},
#  Timestamp('2019-04-24 22:00:00'): {'Cat1_24hour': 0.5284661956567368,
#   'Cat1_48hour': 0.01924327986638054,
#   'Cat2_categorical_48hour': 0.25122026300849293,
#   'LR_2': 1.9316883631635133,
#   'LR_2_7': 0.8855293336052941,
#   'LR_2_7_w_date': 1.9140737237416205,
#   'LR_7': 0.9798117993696804,
#   'naive_2': 0.7049406340644705,
#   'naive_7': 2.107846017623824,
#   'ygur_rima_preds_datetime': 0.18252381714616817},
#  Timestamp('2019-04-24 23:00:00'): {'Cat1_24hour': 1.1114049850141792,
#   'Cat1_48hour': 1.7980579734639761,
#   'Cat2_categorical_48hour': 1.0440996047543118,
#   'LR_2': 0.22571359697191767,
#   'LR_2_7': 1.6101730392873492,
#   'LR_2_7_w_date': 3.0437751821761565,
#   'LR_7': 2.2235817065032113,
#   'naive_2': 0.2449065430273743,
#   'naive_7': 2.6222606964736053,
#   'ygur_rima_preds_datetime': 1.348299195586544},
#  Timestamp('2019-04-25 00:00:00'): {'Cat1_24hour': 0.10142969065518703,
#   'Cat1_48hour': 0.38556996515991626,
#   'Cat2_categorical_48hour': 0.2707332076650428,
#   'LR_2': 0.36398147357616845,
#   'LR_2_7': 0.668182134880856,
#   'LR_2_7_w_date': 0.4999095183278685,
#   'LR_7': 2.3998168917684826,
#   'naive_2': 2.4257038291109745,
#   'naive_7': 1.7962525163020147,
#   'ygur_rima_preds_datetime': 2.102624421779909}}

# %%
pd.DataFrame.from_dict(day_by_day_sort).to_csv("24_nisan_sorted.csv")

# %%
{key:pd.DataFrame.from_dict(day_by_day_sort[key],orient="index").sort_values(by=0).index.tolist() for key in day_by_day_sort.keys() }
# Out:
# {Timestamp('2019-04-24 00:00:00'): ['naive_2',
#   'LR_2',
#   'Cat1_48hour',
#   'LR_2_7_w_date',
#   'Cat1_24hour',
#   'Cat2_categorical_48hour',
#   'LR_2_7',
#   'naive_7',
#   'ygur_rima_preds_datetime',
#   'LR_7'],
#  Timestamp('2019-04-24 01:00:00'): ['naive_2',
#   'LR_2',
#   'Cat2_categorical_48hour',
#   'Cat1_48hour',
#   'LR_2_7',
#   'LR_2_7_w_date',
#   'Cat1_24hour',
#   'naive_7',
#   'ygur_rima_preds_datetime',
#   'LR_7'],
#  Timestamp('2019-04-24 02:00:00'): ['naive_2',
#   'Cat1_48hour',
#   'Cat1_24hour',
#   'LR_2',
#   'Cat2_categorical_48hour',
#   'LR_2_7',
#   'LR_2_7_w_date',
#   'naive_7',
#   'ygur_rima_preds_datetime',
#   'LR_7'],
#  Timestamp('2019-04-24 03:00:00'): ['Cat1_24hour',
#   'Cat1_48hour',
#   'naive_2',
#   'Cat2_categorical_48hour',
#   'LR_2_7',
#   'LR_2',
#   'LR_2_7_w_date',
#   'ygur_rima_preds_datetime',
#   'naive_7',
#   'LR_7'],
#  Timestamp('2019-04-24 04:00:00'): ['Cat1_24hour',
#   'Cat1_48hour',
#   'naive_2',
#   'Cat2_categorical_48hour',
#   'LR_2_7',
#   'LR_2_7_w_date',
#   'LR_2',
#   'naive_7',
#   'ygur_rima_preds_datetime',
#   'LR_7'],
#  Timestamp('2019-04-24 05:00:00'): ['Cat1_48hour',
#   'Cat1_24hour',
#   'naive_2',
#   'LR_2_7',
#   'LR_2',
#   'Cat2_categorical_48hour',
#   'LR_2_7_w_date',
#   'naive_7',
#   'ygur_rima_preds_datetime',
#   'LR_7'],
#  Timestamp('2019-04-24 06:00:00'): ['naive_2',
#   'Cat1_24hour',
#   'Cat1_48hour',
#   'LR_2_7',
#   'Cat2_categorical_48hour',
#   'LR_2',
#   'LR_2_7_w_date',
#   'naive_7',
#   'ygur_rima_preds_datetime',
#   'LR_7'],
#  Timestamp('2019-04-24 07:00:00'): ['naive_2',
#   'Cat1_24hour',
#   'Cat1_48hour',
#   'Cat2_categorical_48hour',
#   'LR_2',
#   'LR_2_7',
#   'LR_2_7_w_date',
#   'ygur_rima_preds_datetime',
#   'naive_7',
#   'LR_7'],
#  Timestamp('2019-04-24 08:00:00'): ['Cat2_categorical_48hour',
#   'Cat1_48hour',
#   'Cat1_24hour',
#   'LR_2',
#   'naive_2',
#   'LR_2_7',
#   'LR_2_7_w_date',
#   'LR_7',
#   'ygur_rima_preds_datetime',
#   'naive_7'],
#  Timestamp('2019-04-24 09:00:00'): ['Cat2_categorical_48hour',
#   'Cat1_48hour',
#   'LR_2_7_w_date',
#   'LR_2_7',
#   'naive_2',
#   'LR_7',
#   'ygur_rima_preds_datetime',
#   'LR_2',
#   'Cat1_24hour',
#   'naive_7'],
#  Timestamp('2019-04-24 10:00:00'): ['Cat1_24hour',
#   'naive_2',
#   'Cat2_categorical_48hour',
#   'LR_2',
#   'LR_2_7_w_date',
#   'LR_2_7',
#   'Cat1_48hour',
#   'LR_7',
#   'ygur_rima_preds_datetime',
#   'naive_7'],
#  Timestamp('2019-04-24 11:00:00'): ['naive_2',
#   'Cat1_24hour',
#   'Cat2_categorical_48hour',
#   'LR_2',
#   'Cat1_48hour',
#   'LR_2_7_w_date',
#   'LR_2_7',
#   'ygur_rima_preds_datetime',
#   'LR_7',
#   'naive_7'],
#  Timestamp('2019-04-24 12:00:00'): ['LR_2',
#   'naive_2',
#   'Cat1_24hour',
#   'Cat2_categorical_48hour',
#   'LR_2_7',
#   'Cat1_48hour',
#   'LR_2_7_w_date',
#   'ygur_rima_preds_datetime',
#   'LR_7',
#   'naive_7'],
#  Timestamp('2019-04-24 13:00:00'): ['LR_2',
#   'naive_2',
#   'Cat1_48hour',
#   'Cat1_24hour',
#   'Cat2_categorical_48hour',
#   'LR_2_7',
#   'LR_2_7_w_date',
#   'LR_7',
#   'ygur_rima_preds_datetime',
#   'naive_7'],
#  Timestamp('2019-04-24 14:00:00'): ['LR_2',
#   'naive_2',
#   'Cat2_categorical_48hour',
#   'Cat1_48hour',
#   'ygur_rima_preds_datetime',
#   'LR_2_7',
#   'Cat1_24hour',
#   'LR_2_7_w_date',
#   'LR_7',
#   'naive_7'],
#  Timestamp('2019-04-24 15:00:00'): ['LR_2',
#   'naive_2',
#   'Cat2_categorical_48hour',
#   'ygur_rima_preds_datetime',
#   'Cat1_48hour',
#   'LR_2_7',
#   'Cat1_24hour',
#   'LR_2_7_w_date',
#   'LR_7',
#   'naive_7'],
#  Timestamp('2019-04-24 16:00:00'): ['LR_2',
#   'naive_2',
#   'Cat2_categorical_48hour',
#   'Cat1_48hour',
#   'Cat1_24hour',
#   'ygur_rima_preds_datetime',
#   'LR_2_7',
#   'LR_7',
#   'LR_2_7_w_date',
#   'naive_7'],
#  Timestamp('2019-04-24 17:00:00'): ['LR_2',
#   'naive_2',
#   'Cat2_categorical_48hour',
#   'Cat1_48hour',
#   'Cat1_24hour',
#   'LR_2_7',
#   'LR_7',
#   'ygur_rima_preds_datetime',
#   'LR_2_7_w_date',
#   'naive_7'],
#  Timestamp('2019-04-24 18:00:00'): ['LR_2',
#   'Cat2_categorical_48hour',
#   'naive_2',
#   'Cat1_24hour',
#   'Cat1_48hour',
#   'ygur_rima_preds_datetime',
#   'LR_2_7',
#   'LR_7',
#   'LR_2_7_w_date',
#   'naive_7'],
#  Timestamp('2019-04-24 19:00:00'): ['Cat2_categorical_48hour',
#   'LR_2',
#   'Cat1_24hour',
#   'naive_2',
#   'Cat1_48hour',
#   'LR_7',
#   'LR_2_7',
#   'LR_2_7_w_date',
#   'ygur_rima_preds_datetime',
#   'naive_7'],
#  Timestamp('2019-04-24 20:00:00'): ['LR_7',
#   'naive_2',
#   'Cat1_48hour',
#   'Cat1_24hour',
#   'Cat2_categorical_48hour',
#   'LR_2_7',
#   'LR_2_7_w_date',
#   'ygur_rima_preds_datetime',
#   'LR_2',
#   'naive_7'],
#  Timestamp('2019-04-24 21:00:00'): ['Cat2_categorical_48hour',
#   'naive_2',
#   'LR_7',
#   'Cat1_48hour',
#   'Cat1_24hour',
#   'ygur_rima_preds_datetime',
#   'LR_2_7',
#   'LR_2_7_w_date',
#   'LR_2',
#   'naive_7'],
#  Timestamp('2019-04-24 22:00:00'): ['Cat1_48hour',
#   'ygur_rima_preds_datetime',
#   'Cat2_categorical_48hour',
#   'Cat1_24hour',
#   'naive_2',
#   'LR_2_7',
#   'LR_7',
#   'LR_2_7_w_date',
#   'LR_2',
#   'naive_7'],
#  Timestamp('2019-04-24 23:00:00'): ['LR_2',
#   'naive_2',
#   'Cat2_categorical_48hour',
#   'Cat1_24hour',
#   'ygur_rima_preds_datetime',
#   'LR_2_7',
#   'Cat1_48hour',
#   'LR_7',
#   'naive_7',
#   'LR_2_7_w_date'],
#  Timestamp('2019-04-25 00:00:00'): ['Cat1_24hour',
#   'Cat2_categorical_48hour',
#   'LR_2',
#   'Cat1_48hour',
#   'LR_2_7_w_date',
#   'LR_2_7',
#   'naive_7',
#   'ygur_rima_preds_datetime',
#   'LR_7',
#   'naive_2']}

# %%
pd.DataFrame.from_dict({key:pd.DataFrame.from_dict(day_by_day_sort[key],orient="index").sort_values(by=0).index.tolist() for key in day_by_day_sort.keys() }).T
# Out:
#                                            0  ...              9
# 2019-04-24 00:00:00                  naive_2  ...           LR_7
# 2019-04-24 01:00:00                  naive_2  ...           LR_7
# 2019-04-24 02:00:00                  naive_2  ...           LR_7
# 2019-04-24 03:00:00              Cat1_24hour  ...           LR_7
# 2019-04-24 04:00:00              Cat1_24hour  ...           LR_7
# 2019-04-24 05:00:00              Cat1_48hour  ...           LR_7
# 2019-04-24 06:00:00                  naive_2  ...           LR_7
# 2019-04-24 07:00:00                  naive_2  ...           LR_7
# 2019-04-24 08:00:00  Cat2_categorical_48hour  ...        naive_7
# 2019-04-24 09:00:00  Cat2_categorical_48hour  ...        naive_7
# 2019-04-24 10:00:00              Cat1_24hour  ...        naive_7
# 2019-04-24 11:00:00                  naive_2  ...        naive_7
# 2019-04-24 12:00:00                     LR_2  ...        naive_7
# 2019-04-24 13:00:00                     LR_2  ...        naive_7
# 2019-04-24 14:00:00                     LR_2  ...        naive_7
# 2019-04-24 15:00:00                     LR_2  ...        naive_7
# 2019-04-24 16:00:00                     LR_2  ...        naive_7
# 2019-04-24 17:00:00                     LR_2  ...        naive_7
# 2019-04-24 18:00:00                     LR_2  ...        naive_7
# 2019-04-24 19:00:00  Cat2_categorical_48hour  ...        naive_7
# 2019-04-24 20:00:00                     LR_7  ...        naive_7
# 2019-04-24 21:00:00  Cat2_categorical_48hour  ...        naive_7
# 2019-04-24 22:00:00              Cat1_48hour  ...        naive_7
# 2019-04-24 23:00:00                     LR_2  ...  LR_2_7_w_date
# 2019-04-25 00:00:00              Cat1_24hour  ...        naive_2
#
# [25 rows x 10 columns]

# %%
mapes
# Out:
# {'Cat1_24hour': 2.6199679513147114,
#  'Cat1_48hour': 2.991182739400095,
#  'Cat2_categorical_24hour': 2.948131281186649,
#  'Cat2_categorical_48hour': 3.2490686862665186,
#  'HW_preds_24hour': 6.152474388551419,
#  'HW_preds_48hour': 7.955785251367757,
#  'Keras_Basic_dense_24': 2.8725964452793478,
#  'Keras_Basic_dense_48': 3.683070359734644,
#  'LR_2': 7.855694573000102,
#  'LR_2_7': 4.989226864853979,
#  'LR_2_7_w_date': 4.053236198257791,
#  'LR_7': 5.22779264475642,
#  'best_case': 0.6872404772042718,
#  'naive_2': 8.15891679451568,
#  'naive_7': 5.208054715113833,
#  'window_14_days_0_buffer': 2.954443548681186,
#  'window_14_days_24_buffer': 3.0125497747885506,
#  'window_14_days_48_buffer': 2.973440981242279,
#  'window_28_days_0_buffer': 3.0170898860443414,
#  'window_28_days_24_buffer': 3.0811627135132427,
#  'window_28_days_48_buffer': 3.0608280930514087,
#  'window_30_days_0_buffer': 3.037566241685234,
#  'window_30_days_24_buffer': 3.080684164685388,
#  'window_30_days_48_buffer': 3.068768495302032,
#  'window_5_days_0_buffer': 3.3465415980949533,
#  'window_5_days_24_buffer': 3.9439645735046374,
#  'window_5_days_48_buffer': 3.9673946126574373,
#  'window_7_days_0_buffer': 3.0602356848494683,
#  'window_7_days_24_buffer': 3.3748489693825587,
#  'window_7_days_48_buffer': 3.4101804675734546,
#  'ygur_rima_preds_datetime': 3.4653294353157422}

# %%
pd.DataFrame.from_dict(mapes,orient="index").to_excel("Mapes.xlsx")

# %%
# preds.loc[1344,"Datetime"]=pd.to_datetime("2019-03-29 00:00:00")

# %%
np.unique([i.split("_")[1] for i in weather_data.columns if i!="Datetime"])
# Out:
# array(['Adana / Incirlik', 'Adana / Sakirpasa', 'Afyon', 'Akhisar',
#        'Ankara / Esenboga', 'Ankara / Etimesgut', 'Antalya', 'Aydin',
#        'Balikesir', 'Bandirma', 'Batman', 'Bodrum', 'Canakkale',
#        'Dalaman', 'Diyarbakir', 'Elazig', 'Erzincan', 'Erzurum',
#        'Eskisehir', 'Gaziantep', 'Iskenderun', 'Isparta',
#        'Isparta / Gölba??', 'Istanbul / Ataturk',
#        'Izmir / Adnan Menderes', 'Izmir / Cigli', 'Kars',
#        'Kayseri / Erkilet', 'Konya', 'Malatya / Erhac', 'Merzifon',
#        'Murted Tur-Afb', 'Sivas', 'Tokat', 'Trabzon', 'Usak', 'Van',
#        'Zonguldak'], dtype='<U22')

# %% [markdown]
# ## decision tree

# %%
weather_data=pd.read_csv('kubi_temp_humid_wind_data_20151231-2020-04-02.csv')
weather_data=weather_data.rename(columns={"rounded_date":"Datetime"})
weather_data["Datetime"]=pd.to_datetime(weather_data["Datetime"])
cons_holiday_binary=pd.merge(cons_holiday_binary,weather_data,on="Datetime",how="left")
cat_df_1=cons_holiday_binary[["Datetime"] + [i for i in cons_holiday_binary.columns if i.startswith("is_")]].copy()
cat_df_1["Hour"]=cat_df_1["Datetime"].apply(lambda x:x.hour).astype(int)
cat_df_1["Day"]=cat_df_1["Datetime"].apply(lambda x:x.day).astype(int)
cat_df_1["Month"]=cat_df_1["Datetime"].apply(lambda x:x.month).astype(int)
cat_df_1["weekday"]=cat_df_1["Datetime"].apply(lambda x: x.weekday()).astype(int)

# %%
train_df=pd.merge(preds.drop(columns=["chosen"]),cat_df_1,on="Datetime",how="left")

# %%
from sklearn.tree import DecisionTreeClassifier

def dt_window_approach(n,buffer):
    ## n'den baslayıp surkeli growing olarak gidiyor windows
    shift_timespan=n*24
    print("decision tree window approach with n = {}, buffer = {}".format(n,buffer))
    predicted_model=["unknown"]*(shift_timespan+buffer)
    ranking=["unknown"]*(shift_timespan+buffer)

    for i in tqdm(range(shift_timespan,len(preds)-buffer)):
        # buffer koy
        train_df_epoch=train_df.iloc[:i].reset_index()
        valid_df=train_df.iloc[i+buffer:i+buffer+1].reset_index()
        tree=DecisionTreeClassifier(max_depth=8,min_samples_leaf=10)
        tree.fit(train_df.drop(columns=["best_model","Datetime"]),train_df["best_model"])
        # random forestt rreggrressor

        pred=tree.predict(pd.DataFrame(valid_df).drop(columns=["best_model","Datetime"]))
        a=tree.classes_.tolist()
        b=tree.predict_proba(pd.DataFrame(valid_df).drop(columns=["best_model","Datetime"])).tolist()[0]
        ranking.append(dict(zip(a,b)))
        # predict proba
        predicted_model.append(pred[0])
    preds["tree_{}_n_{}_bufferpredicted".format(n,buffer)]=predicted_model
    return predicted_model,ranking

# %%
combins=np.concatenate([[(j,i) for i in [24,48]] for j in [7,14,28]])
rankings={}
predictions_={}
for n,buffer in combins:
    pred_model_list,ranking=dt_window_approach(n,buffer)
    rankings["n_{}_buffer_{}".format(n,buffer)]=ranking
    predictions_["n_{}_buffer_{}".format(n,buffer)]=pred_model_list
# Out:
# decision tree window approach with n = 7, buffer = 24
# HBox(children=(FloatProgress(value=0.0, max=9336.0), HTML(value='')))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-7acf12bbf781> in <module>()
#       3 predictions_={}
#       4 for n,buffer in combins:
# ----> 5     pred_model_list,ranking=dt_window_approach(n,buffer)
#       6     rankings["n_{}_buffer_{}".format(n,buffer)]=ranking
#       7     predictions_["n_{}_buffer_{}".format(n,buffer)]=pred_model_list
#
# <ipython-input-29-7e58593da4ae> in dt_window_approach(n, buffer)
#      16         # random forestt rreggrressor
#      17
# ---> 18         pred=tree.predict(pd.DataFrame(valid_df).drop(columns=["best_model","Datetime"]))
#      19         a=tree.classes_.tolist()
#      20         b=tree.predict_proba(pd.DataFrame(valid_df).drop(columns=["best_model","Datetime"])).tolist()[0]
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     417         """
#     418         check_is_fitted(self)
# --> 419         X = self._validate_X_predict(X, check_input)
#     420         proba = self.tree_.predict(X)
#     421         n_samples = X.shape[0]
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     389                              "match the input. Model n_features is %s and "
#     390                              "input n_features is %s "
# --> 391                              % (self.n_features_, n_features))
#     392
#     393         return X
#
# ValueError: Number of features of the model must match the input. Model n_features is 59 and input n_features is 60

# %%
preds
# Out:
#                 Datetime  ...  tree_14_n_48_bufferpredicted
# 0    2019-02-01 00:00:00  ...                       unknown
# 1    2019-02-01 01:00:00  ...                       unknown
# 2    2019-02-01 02:00:00  ...                       unknown
# 3    2019-02-01 03:00:00  ...                       unknown
# 4    2019-02-01 04:00:00  ...                       unknown
# ...                  ...  ...                           ...
# 9523 2020-03-03 19:00:00  ...          Keras_Basic_dense_48
# 9524 2020-03-03 20:00:00  ...          Keras_Basic_dense_48
# 9525 2020-03-03 21:00:00  ...          Keras_Basic_dense_48
# 9526 2020-03-03 22:00:00  ...          Keras_Basic_dense_48
# 9527 2020-03-03 23:00:00  ...          Keras_Basic_dense_48
#
# [9528 rows x 23 columns]

# %%
fig=tree.fit(train_df.drop(columns=["best_model","Datetime"]),train_df["best_model"])
_, ax = plt.subplots(figsize=(15, 15))  # whatever size you want
plot_tree(fig,ax=ax,feature_names=train_df.drop(columns=["Datetime","best_model"]).columns,fontsize=16);

# %%
from sklearn.tree import DecisionTreeClassifier

shift_timespan=30*24
predicted_model=["unknown"]*shift_timespan
ranking=["unknown"]*shift_timespan
for i in tqdm(range(shift_timespan,len(preds),24)):
    # buffer koy
    train_df=preds[["Datetime","best_model"]].iloc[:i]
    train_df=pd.merge(train_df,cat_df_1,how="left",on="Datetime")
    valid_df=train_df.iloc[-24:]
    train_df=train_df.iloc[:i-24]
    tree=DecisionTreeClassifier(max_depth=16,min_samples_leaf=10)
    tree.fit(train_df.drop(columns=["best_model","Datetime"]),train_df["best_model"])
    # random forestt rreggrressor
    pred=tree.predict(pd.DataFrame(valid_df).drop(columns=["best_model","Datetime"]))
    # a=tree.classes_.tolist()
    # b=tree.predict_proba(pd.DataFrame(valid_df).T.drop(columns=["best_model","Datetime"])).tolist()[0]
    # ranking.append(dict(zip(a,b)))
    # predict proba
    predicted_model=np.concatenate((np.array(predicted_model),pred))
# preds["ranking"]=ranking
preds["tree_predicted"]=predicted_model
preds

# %%
# parameterler
# tahminleri de eklemek
# gün bazlı seyi kacırıyoruz saat saat baktıgımız için, günün bütününe dair

# %%
2.540852726450188

# %%
mapes_tree={}
for col in [i for i in preds.columns if "tree" in i ]:
    mapes_=preds.loc[preds[col]!="unknown"].apply(lambda x: mean_absolute_percentage_error(x["reel"],x[x[col]]),axis=1)
    mapes_tree[col]=mapes_.mean()

# %%
mapes_tree
# Out:
# {'tree_14_n_24_bufferpredicted': 3.3000047383774977,
#  'tree_14_n_48_bufferpredicted': 4.33701975062609,
#  'tree_7_n_24_bufferpredicted': 3.2858896479918704,
#  'tree_7_n_48_bufferpredicted': 4.331831216842988}

# %%
preds.iloc[[8024]]

# %%
preds[preds["tree_predicted"]!="unknown"]["tree_predicted"].value_counts()

# %%
preds

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
from sklearn.metrics import confusion_matrix
for col in ["chosen","chosen_5","chosen_14","tree_predicted"]:
    pah_="drive/My Drive/colab_datas/IE 492/kubi_preds/eval_plots/conf_matrices/"+col
    if not os.path.exists(pah_):
        os.mkdir(pah_)
    unq_pred=preds.loc[preds[col]!="unknown"].reset_index(drop=True)
    clss=labels=unq_pred[col].unique().tolist()
    y_true=unq_pred["best_model"].values
    y_pred=unq_pred[col].values
    cnf_matrix = confusion_matrix(y_true, y_pred,labels=clss)
    np.set_printoptions(precision=2)
    plt.figure(figsize=(15,15))
    plot_confusion_matrix(cnf_matrix, classes=clss,
                        title='Confusion matrix of {}, without normalization'.format(col))
    plt.savefig(pah_+"/conf_matrix.png")

# %%
preds["best_case"]=preds.apply(lambda x:x[x["best_model"]],axis=1)
preds["window_case"]=preds.apply(lambda x:x[x["chosen"]] if x["chosen"]!="unknown" else 0,axis=1)
preds["tree_case"]=preds.apply(lambda x:x[x["tree_predicted"]] if x["tree_predicted"]!="unknown" else 0,axis=1)

# %%
for col in preds.columns[1:-5]:
    eval_function(col,preds["reel"],preds[col],preds)

# %%
eval_function("best_case",preds["reel"],preds["best_case"],preds)

# %%
pred_wo_unk=preds.loc[preds["window_case"]!=0].reset_index(drop=True)
eval_function("meta_window_case",pred_wo_unk["reel"],pred_wo_unk["window_case"],pred_wo_unk)

# %%
pred_wo_unk=preds.loc[preds["tree_case"]!=0].reset_index(drop=True)
eval_function("meta_tree_case",pred_wo_unk["reel"],pred_wo_unk["tree_case"],pred_wo_unk)

# %%
pd.DataFrame.from_dict(mapes,orient="index")
