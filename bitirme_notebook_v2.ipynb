# %% [markdown]
# <a href="https://colab.research.google.com/github/yakaralar/IE492/blob/master/bitirme_notebook_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import glob
import shutil
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
shutil.copy("drive/My Drive/colab_datas/IE 492/weather_turkey_processed.zip","./")
# !unzip weather_turkey_processed.zip
# Out:
# Archive:  weather_turkey_processed.zip
#    creating: weather_turkey_processed/
#   inflating: weather_turkey_processed/36_26.5.csv
#   inflating: weather_turkey_processed/38.5_42.csv
#   inflating: weather_turkey_processed/36_26.csv
#   inflating: weather_turkey_processed/36_27.5.csv
#   inflating: weather_turkey_processed/36_27.csv
#   inflating: weather_turkey_processed/36_28.5.csv
#   inflating: weather_turkey_processed/36_28.csv
#   inflating: weather_turkey_processed/36_29.5.csv
#   inflating: weather_turkey_processed/36_29.csv
#   inflating: weather_turkey_processed/36_30.5.csv
#   inflating: weather_turkey_processed/36_30.csv
#   inflating: weather_turkey_processed/36_31.5.csv
#   inflating: weather_turkey_processed/36_31.csv
#   inflating: weather_turkey_processed/36_32.5.csv
#   inflating: weather_turkey_processed/36_32.csv
#   inflating: weather_turkey_processed/36_33.5.csv
#   inflating: weather_turkey_processed/36_33.csv
#   inflating: weather_turkey_processed/36_34.5.csv
#   inflating: weather_turkey_processed/36_34.csv
#   inflating: weather_turkey_processed/36_35.5.csv
#   inflating: weather_turkey_processed/36_35.csv
#   inflating: weather_turkey_processed/36_36.5.csv
#   inflating: weather_turkey_processed/36_36.csv
#   inflating: weather_turkey_processed/36_37.5.csv
#   inflating: weather_turkey_processed/36_37.csv
#   inflating: weather_turkey_processed/36_38.5.csv
#   inflating: weather_turkey_processed/36_38.csv
#   inflating: weather_turkey_processed/36_39.5.csv
#   inflating: weather_turkey_processed/36_39.csv
#   inflating: weather_turkey_processed/36_40.5.csv
#   inflating: weather_turkey_processed/36_40.csv
#   inflating: weather_turkey_processed/36_41.5.csv
#   inflating: weather_turkey_processed/36_41.csv
#   inflating: weather_turkey_processed/36_42.5.csv
#   inflating: weather_turkey_processed/36_42.csv
#   inflating: weather_turkey_processed/36_43.5.csv
#   inflating: weather_turkey_processed/36_43.csv
#   inflating: weather_turkey_processed/36_44.5.csv
#   inflating: weather_turkey_processed/36_44.csv
#   inflating: weather_turkey_processed/36_45.csv
#   inflating: weather_turkey_processed/36.5_26.5.csv
#   inflating: weather_turkey_processed/36.5_26.csv
#   inflating: weather_turkey_processed/36.5_27.5.csv
#   inflating: weather_turkey_processed/36.5_27.csv
#   inflating: weather_turkey_processed/36.5_28.5.csv
#   inflating: weather_turkey_processed/36.5_28.csv
#   inflating: weather_turkey_processed/36.5_29.5.csv
#   inflating: weather_turkey_processed/36.5_29.csv
#   inflating: weather_turkey_processed/36.5_30.5.csv
#   inflating: weather_turkey_processed/36.5_30.csv
#   inflating: weather_turkey_processed/36.5_31.5.csv
#   inflating: weather_turkey_processed/36.5_31.csv
#   inflating: weather_turkey_processed/36.5_32.5.csv
#   inflating: weather_turkey_processed/36.5_32.csv
#   inflating: weather_turkey_processed/36.5_33.5.csv
#   inflating: weather_turkey_processed/36.5_33.csv
#   inflating: weather_turkey_processed/36.5_34.5.csv
#   inflating: weather_turkey_processed/36.5_34.csv
#   inflating: weather_turkey_processed/36.5_35.5.csv
#   inflating: weather_turkey_processed/36.5_35.csv
#   inflating: weather_turkey_processed/36.5_36.5.csv
#   inflating: weather_turkey_processed/36.5_36.csv
#   inflating: weather_turkey_processed/36.5_37.5.csv
#   inflating: weather_turkey_processed/36.5_37.csv
#   inflating: weather_turkey_processed/36.5_38.5.csv
#   inflating: weather_turkey_processed/36.5_38.csv
#   inflating: weather_turkey_processed/36.5_39.5.csv
#   inflating: weather_turkey_processed/36.5_39.csv
#   inflating: weather_turkey_processed/36.5_40.5.csv
#   inflating: weather_turkey_processed/36.5_40.csv
#   inflating: weather_turkey_processed/36.5_41.5.csv
#   inflating: weather_turkey_processed/36.5_41.csv
#   inflating: weather_turkey_processed/36.5_42.5.csv
#   inflating: weather_turkey_processed/36.5_42.csv
#   inflating: weather_turkey_processed/36.5_43.5.csv
#   inflating: weather_turkey_processed/36.5_43.csv
#   inflating: weather_turkey_processed/36.5_44.5.csv
#   inflating: weather_turkey_processed/36.5_44.csv
#   inflating: weather_turkey_processed/36.5_45.csv
#   inflating: weather_turkey_processed/37_26.5.csv
#   inflating: weather_turkey_processed/37_26.csv
#   inflating: weather_turkey_processed/37_27.5.csv
#   inflating: weather_turkey_processed/37_27.csv
#   inflating: weather_turkey_processed/37_28.5.csv
#   inflating: weather_turkey_processed/37_28.csv
#   inflating: weather_turkey_processed/37_29.5.csv
#   inflating: weather_turkey_processed/37_29.csv
#   inflating: weather_turkey_processed/37_30.5.csv
#   inflating: weather_turkey_processed/37_30.csv
#   inflating: weather_turkey_processed/37_31.5.csv
#   inflating: weather_turkey_processed/37_31.csv
#   inflating: weather_turkey_processed/37_32.5.csv
#   inflating: weather_turkey_processed/37_32.csv
#   inflating: weather_turkey_processed/37_33.5.csv
#   inflating: weather_turkey_processed/37_33.csv
#   inflating: weather_turkey_processed/37_34.5.csv
#   inflating: weather_turkey_processed/37_34.csv
#   inflating: weather_turkey_processed/37_35.5.csv
#   inflating: weather_turkey_processed/37_35.csv
#   inflating: weather_turkey_processed/37_36.5.csv
#   inflating: weather_turkey_processed/37_36.csv
#   inflating: weather_turkey_processed/37_37.5.csv
#   inflating: weather_turkey_processed/37_37.csv
#   inflating: weather_turkey_processed/37_38.5.csv
#   inflating: weather_turkey_processed/37_38.csv
#   inflating: weather_turkey_processed/37_39.5.csv
#   inflating: weather_turkey_processed/37_39.csv
#   inflating: weather_turkey_processed/37_40.5.csv
#   inflating: weather_turkey_processed/37_40.csv
#   inflating: weather_turkey_processed/37_41.5.csv
#   inflating: weather_turkey_processed/37_41.csv
#   inflating: weather_turkey_processed/37_42.5.csv
#   inflating: weather_turkey_processed/37_42.csv
#   inflating: weather_turkey_processed/37_43.5.csv
#   inflating: weather_turkey_processed/37_43.csv
#   inflating: weather_turkey_processed/37_44.5.csv
#   inflating: weather_turkey_processed/37_44.csv
#   inflating: weather_turkey_processed/37_45.csv
#   inflating: weather_turkey_processed/37.5_26.5.csv
#   inflating: weather_turkey_processed/37.5_26.csv
#   inflating: weather_turkey_processed/37.5_27.5.csv
#   inflating: weather_turkey_processed/37.5_27.csv
#   inflating: weather_turkey_processed/37.5_28.5.csv
#   inflating: weather_turkey_processed/37.5_28.csv
#   inflating: weather_turkey_processed/37.5_29.5.csv
#   inflating: weather_turkey_processed/37.5_29.csv
#   inflating: weather_turkey_processed/37.5_30.5.csv
#   inflating: weather_turkey_processed/37.5_30.csv
#   inflating: weather_turkey_processed/37.5_31.5.csv
#   inflating: weather_turkey_processed/37.5_31.csv
#   inflating: weather_turkey_processed/37.5_32.5.csv
#   inflating: weather_turkey_processed/37.5_32.csv
#   inflating: weather_turkey_processed/37.5_33.5.csv
#   inflating: weather_turkey_processed/37.5_33.csv
#   inflating: weather_turkey_processed/37.5_34.5.csv
#   inflating: weather_turkey_processed/37.5_34.csv
#   inflating: weather_turkey_processed/37.5_35.5.csv
#   inflating: weather_turkey_processed/37.5_35.csv
#   inflating: weather_turkey_processed/37.5_36.5.csv
#   inflating: weather_turkey_processed/37.5_36.csv
#   inflating: weather_turkey_processed/37.5_37.5.csv
#   inflating: weather_turkey_processed/37.5_37.csv
#   inflating: weather_turkey_processed/37.5_38.5.csv
#   inflating: weather_turkey_processed/37.5_38.csv
#   inflating: weather_turkey_processed/37.5_39.5.csv
#   inflating: weather_turkey_processed/37.5_39.csv
#   inflating: weather_turkey_processed/37.5_40.5.csv
#   inflating: weather_turkey_processed/38_26.5.csv
#   inflating: weather_turkey_processed/37.5_40.csv
#   inflating: weather_turkey_processed/37.5_41.5.csv
#   inflating: weather_turkey_processed/37.5_41.csv
#   inflating: weather_turkey_processed/37.5_42.5.csv
#   inflating: weather_turkey_processed/37.5_42.csv
#   inflating: weather_turkey_processed/37.5_43.5.csv
#   inflating: weather_turkey_processed/37.5_43.csv
#   inflating: weather_turkey_processed/37.5_44.5.csv
#   inflating: weather_turkey_processed/37.5_44.csv
#   inflating: weather_turkey_processed/37.5_45.csv
#   inflating: weather_turkey_processed/38_26.csv
#   inflating: weather_turkey_processed/38_27.5.csv
#   inflating: weather_turkey_processed/38_27.csv
#   inflating: weather_turkey_processed/40.5_28.5.csv
#   inflating: weather_turkey_processed/38_28.5.csv
#   inflating: weather_turkey_processed/38_28.csv
#   inflating: weather_turkey_processed/38_29.5.csv
#   inflating: weather_turkey_processed/38_29.csv
#   inflating: weather_turkey_processed/38_30.5.csv
#   inflating: weather_turkey_processed/38_30.csv
#   inflating: weather_turkey_processed/38_31.5.csv
#   inflating: weather_turkey_processed/38_31.csv
#   inflating: weather_turkey_processed/38_32.5.csv
#   inflating: weather_turkey_processed/38_32.csv
#   inflating: weather_turkey_processed/38_33.5.csv
#   inflating: weather_turkey_processed/38_33.csv
#   inflating: weather_turkey_processed/38_34.5.csv
#   inflating: weather_turkey_processed/38_34.csv
#   inflating: weather_turkey_processed/38_35.5.csv
#   inflating: weather_turkey_processed/38_35.csv
#   inflating: weather_turkey_processed/38_36.5.csv
#   inflating: weather_turkey_processed/38_36.csv
#   inflating: weather_turkey_processed/38_37.5.csv
#   inflating: weather_turkey_processed/38.5_40.csv
#   inflating: weather_turkey_processed/38_37.csv
#   inflating: weather_turkey_processed/38_38.5.csv
#   inflating: weather_turkey_processed/38_38.csv
#   inflating: weather_turkey_processed/38_39.5.csv
#   inflating: weather_turkey_processed/38_39.csv
#   inflating: weather_turkey_processed/38_40.5.csv
#   inflating: weather_turkey_processed/38_40.csv
#   inflating: weather_turkey_processed/38_41.5.csv
#   inflating: weather_turkey_processed/38_41.csv
#   inflating: weather_turkey_processed/38_42.5.csv
#   inflating: weather_turkey_processed/38_42.csv
#   inflating: weather_turkey_processed/38_43.5.csv
#   inflating: weather_turkey_processed/38_43.csv
#   inflating: weather_turkey_processed/38_44.5.csv
#   inflating: weather_turkey_processed/38_44.csv
#   inflating: weather_turkey_processed/38_45.csv
#   inflating: weather_turkey_processed/38.5_26.5.csv
#   inflating: weather_turkey_processed/38.5_26.csv
#   inflating: weather_turkey_processed/38.5_27.5.csv
#   inflating: weather_turkey_processed/38.5_27.csv
#   inflating: weather_turkey_processed/38.5_28.5.csv
#   inflating: weather_turkey_processed/38.5_28.csv
#   inflating: weather_turkey_processed/38.5_29.5.csv
#   inflating: weather_turkey_processed/38.5_29.csv
#   inflating: weather_turkey_processed/38.5_30.5.csv
#   inflating: weather_turkey_processed/38.5_30.csv
#   inflating: weather_turkey_processed/38.5_31.5.csv
#   inflating: weather_turkey_processed/38.5_31.csv
#   inflating: weather_turkey_processed/38.5_32.5.csv
#   inflating: weather_turkey_processed/38.5_32.csv
#   inflating: weather_turkey_processed/38.5_33.5.csv
#   inflating: weather_turkey_processed/38.5_33.csv
#   inflating: weather_turkey_processed/38.5_34.5.csv
#   inflating: weather_turkey_processed/38.5_34.csv
#   inflating: weather_turkey_processed/38.5_35.5.csv
#   inflating: weather_turkey_processed/38.5_35.csv
#   inflating: weather_turkey_processed/38.5_36.5.csv
#   inflating: weather_turkey_processed/38.5_36.csv
#   inflating: weather_turkey_processed/38.5_37.5.csv
#   inflating: weather_turkey_processed/38.5_37.csv
#   inflating: weather_turkey_processed/38.5_38.5.csv
#   inflating: weather_turkey_processed/38.5_38.csv
#   inflating: weather_turkey_processed/38.5_39.5.csv
#   inflating: weather_turkey_processed/38.5_39.csv
#   inflating: weather_turkey_processed/38.5_40.5.csv
#   inflating: weather_turkey_processed/38.5_41.5.csv
#   inflating: weather_turkey_processed/38.5_41.csv
#   inflating: weather_turkey_processed/38.5_42.5.csv
#   inflating: weather_turkey_processed/42_43.5.csv
#   inflating: weather_turkey_processed/38.5_43.5.csv
#   inflating: weather_turkey_processed/38.5_43.csv
#   inflating: weather_turkey_processed/38.5_44.5.csv
#   inflating: weather_turkey_processed/38.5_44.csv
#   inflating: weather_turkey_processed/38.5_45.csv
#   inflating: weather_turkey_processed/39_26.5.csv
#   inflating: weather_turkey_processed/39_26.csv
#   inflating: weather_turkey_processed/39_27.5.csv
#   inflating: weather_turkey_processed/39_27.csv
#   inflating: weather_turkey_processed/39_28.5.csv
#   inflating: weather_turkey_processed/39_28.csv
#   inflating: weather_turkey_processed/39_29.5.csv
#   inflating: weather_turkey_processed/39_29.csv
#   inflating: weather_turkey_processed/39_30.5.csv
#   inflating: weather_turkey_processed/39_30.csv
#   inflating: weather_turkey_processed/39_31.5.csv
#   inflating: weather_turkey_processed/39_31.csv
#   inflating: weather_turkey_processed/39_32.5.csv
#   inflating: weather_turkey_processed/39_32.csv
#   inflating: weather_turkey_processed/39_33.5.csv
#   inflating: weather_turkey_processed/39_33.csv
#   inflating: weather_turkey_processed/39_34.5.csv
#   inflating: weather_turkey_processed/39_34.csv
#   inflating: weather_turkey_processed/39_35.5.csv
#   inflating: weather_turkey_processed/39_35.csv
#   inflating: weather_turkey_processed/39_36.5.csv
#   inflating: weather_turkey_processed/39_36.csv
#   inflating: weather_turkey_processed/39_37.5.csv
#   inflating: weather_turkey_processed/39_37.csv
#   inflating: weather_turkey_processed/39_38.5.csv
#   inflating: weather_turkey_processed/39_38.csv
#   inflating: weather_turkey_processed/39_39.5.csv
#   inflating: weather_turkey_processed/39_39.csv
#   inflating: weather_turkey_processed/39_40.5.csv
#   inflating: weather_turkey_processed/39_40.csv
#   inflating: weather_turkey_processed/39_41.5.csv
#   inflating: weather_turkey_processed/39_41.csv
#   inflating: weather_turkey_processed/39_42.5.csv
#   inflating: weather_turkey_processed/39_42.csv
#   inflating: weather_turkey_processed/39_43.5.csv
#   inflating: weather_turkey_processed/39_43.csv
#   inflating: weather_turkey_processed/39_44.5.csv
#   inflating: weather_turkey_processed/39_44.csv
#   inflating: weather_turkey_processed/39_45.csv
#   inflating: weather_turkey_processed/39.5_26.5.csv
#   inflating: weather_turkey_processed/39.5_26.csv
#   inflating: weather_turkey_processed/39.5_27.5.csv
#   inflating: weather_turkey_processed/39.5_27.csv
#   inflating: weather_turkey_processed/39.5_28.5.csv
#   inflating: weather_turkey_processed/39.5_28.csv
#   inflating: weather_turkey_processed/39.5_29.5.csv
#   inflating: weather_turkey_processed/39.5_29.csv
#   inflating: weather_turkey_processed/39.5_30.5.csv
#   inflating: weather_turkey_processed/39.5_30.csv
#   inflating: weather_turkey_processed/39.5_31.5.csv
#   inflating: weather_turkey_processed/39.5_31.csv
#   inflating: weather_turkey_processed/39.5_32.5.csv
#   inflating: weather_turkey_processed/39.5_32.csv
#   inflating: weather_turkey_processed/39.5_33.5.csv
#   inflating: weather_turkey_processed/39.5_33.csv
#   inflating: weather_turkey_processed/39.5_34.5.csv
#   inflating: weather_turkey_processed/39.5_34.csv
#   inflating: weather_turkey_processed/39.5_35.5.csv
#   inflating: weather_turkey_processed/39.5_35.csv
#   inflating: weather_turkey_processed/39.5_36.5.csv
#   inflating: weather_turkey_processed/39.5_36.csv
#   inflating: weather_turkey_processed/39.5_37.5.csv
#   inflating: weather_turkey_processed/39.5_37.csv
#   inflating: weather_turkey_processed/39.5_38.5.csv
#   inflating: weather_turkey_processed/39.5_38.csv
#   inflating: weather_turkey_processed/39.5_39.5.csv
#   inflating: weather_turkey_processed/39.5_39.csv
#   inflating: weather_turkey_processed/39.5_40.5.csv
#   inflating: weather_turkey_processed/39.5_40.csv
#   inflating: weather_turkey_processed/39.5_41.5.csv
#   inflating: weather_turkey_processed/40_43.csv
#   inflating: weather_turkey_processed/39.5_41.csv
#   inflating: weather_turkey_processed/39.5_42.5.csv
#   inflating: weather_turkey_processed/39.5_42.csv
#   inflating: weather_turkey_processed/39.5_43.5.csv
#   inflating: weather_turkey_processed/39.5_43.csv
#   inflating: weather_turkey_processed/39.5_44.5.csv
#   inflating: weather_turkey_processed/39.5_44.csv
#   inflating: weather_turkey_processed/39.5_45.csv
#   inflating: weather_turkey_processed/40_26.5.csv
#   inflating: weather_turkey_processed/40_26.csv
#   inflating: weather_turkey_processed/40_27.5.csv
#   inflating: weather_turkey_processed/40_27.csv
#   inflating: weather_turkey_processed/40_28.5.csv
#   inflating: weather_turkey_processed/40_28.csv
#   inflating: weather_turkey_processed/40_29.5.csv
#   inflating: weather_turkey_processed/40_29.csv
#   inflating: weather_turkey_processed/40_30.5.csv
#   inflating: weather_turkey_processed/40_30.csv
#   inflating: weather_turkey_processed/40_31.5.csv
#   inflating: weather_turkey_processed/40_31.csv
#   inflating: weather_turkey_processed/40_32.5.csv
#   inflating: weather_turkey_processed/40_32.csv
#   inflating: weather_turkey_processed/40_33.5.csv
#   inflating: weather_turkey_processed/40_33.csv
#   inflating: weather_turkey_processed/40_34.5.csv
#   inflating: weather_turkey_processed/40_34.csv
#   inflating: weather_turkey_processed/40_35.5.csv
#   inflating: weather_turkey_processed/40_35.csv
#   inflating: weather_turkey_processed/40_36.5.csv
#   inflating: weather_turkey_processed/40_36.csv
#   inflating: weather_turkey_processed/40_37.5.csv
#   inflating: weather_turkey_processed/40_37.csv
#   inflating: weather_turkey_processed/40_38.5.csv
#   inflating: weather_turkey_processed/40_38.csv
#   inflating: weather_turkey_processed/40_39.5.csv
#   inflating: weather_turkey_processed/40_39.csv
#   inflating: weather_turkey_processed/40_40.5.csv
#   inflating: weather_turkey_processed/40_40.csv
#   inflating: weather_turkey_processed/40_41.5.csv
#   inflating: weather_turkey_processed/40_41.csv
#   inflating: weather_turkey_processed/40_42.5.csv
#   inflating: weather_turkey_processed/40_42.csv
#   inflating: weather_turkey_processed/40_43.5.csv
#   inflating: weather_turkey_processed/40_44.5.csv
#   inflating: weather_turkey_processed/40_44.csv
#   inflating: weather_turkey_processed/40_45.csv
#   inflating: weather_turkey_processed/40.5_26.5.csv
#   inflating: weather_turkey_processed/40.5_26.csv
#   inflating: weather_turkey_processed/40.5_27.5.csv
#   inflating: weather_turkey_processed/40.5_27.csv
#   inflating: weather_turkey_processed/40.5_28.csv
#   inflating: weather_turkey_processed/40.5_29.5.csv
#   inflating: weather_turkey_processed/40.5_29.csv
#   inflating: weather_turkey_processed/40.5_30.5.csv
#   inflating: weather_turkey_processed/40.5_30.csv
#   inflating: weather_turkey_processed/40.5_31.5.csv
#   inflating: weather_turkey_processed/40.5_31.csv
#   inflating: weather_turkey_processed/40.5_32.5.csv
#   inflating: weather_turkey_processed/40.5_32.csv
#   inflating: weather_turkey_processed/40.5_33.5.csv
#   inflating: weather_turkey_processed/40.5_33.csv
#   inflating: weather_turkey_processed/40.5_34.5.csv
#   inflating: weather_turkey_processed/40.5_34.csv
#   inflating: weather_turkey_processed/40.5_35.5.csv
#   inflating: weather_turkey_processed/40.5_35.csv
#   inflating: weather_turkey_processed/40.5_36.5.csv
#   inflating: weather_turkey_processed/40.5_36.csv
#   inflating: weather_turkey_processed/40.5_37.5.csv
#   inflating: weather_turkey_processed/40.5_37.csv
#   inflating: weather_turkey_processed/40.5_38.5.csv
#   inflating: weather_turkey_processed/40.5_38.csv
#   inflating: weather_turkey_processed/40.5_39.5.csv
#   inflating: weather_turkey_processed/40.5_39.csv
#   inflating: weather_turkey_processed/40.5_40.5.csv
#   inflating: weather_turkey_processed/40.5_40.csv
#   inflating: weather_turkey_processed/40.5_41.5.csv
#   inflating: weather_turkey_processed/40.5_41.csv
#   inflating: weather_turkey_processed/40.5_42.5.csv
#   inflating: weather_turkey_processed/40.5_42.csv
#   inflating: weather_turkey_processed/40.5_43.5.csv
#   inflating: weather_turkey_processed/40.5_43.csv
#   inflating: weather_turkey_processed/40.5_44.5.csv
#   inflating: weather_turkey_processed/40.5_44.csv
#   inflating: weather_turkey_processed/40.5_45.csv
#   inflating: weather_turkey_processed/41_26.5.csv
#   inflating: weather_turkey_processed/41_26.csv
#   inflating: weather_turkey_processed/41_27.5.csv
#   inflating: weather_turkey_processed/41_27.csv
#   inflating: weather_turkey_processed/41_28.5.csv
#   inflating: weather_turkey_processed/41_28.csv
#   inflating: weather_turkey_processed/41_29.5.csv
#   inflating: weather_turkey_processed/41_29.csv
#   inflating: weather_turkey_processed/41_30.5.csv
#   inflating: weather_turkey_processed/41_30.csv
#   inflating: weather_turkey_processed/41_31.5.csv
#   inflating: weather_turkey_processed/41_31.csv
#   inflating: weather_turkey_processed/41_32.5.csv
#   inflating: weather_turkey_processed/41_32.csv
#   inflating: weather_turkey_processed/41_33.5.csv
#   inflating: weather_turkey_processed/41_33.csv
#   inflating: weather_turkey_processed/41_34.5.csv
#   inflating: weather_turkey_processed/41_34.csv
#   inflating: weather_turkey_processed/41_35.5.csv
#   inflating: weather_turkey_processed/41_35.csv
#   inflating: weather_turkey_processed/41_36.5.csv
#   inflating: weather_turkey_processed/41_36.csv
#   inflating: weather_turkey_processed/41_37.5.csv
#   inflating: weather_turkey_processed/41_37.csv
#   inflating: weather_turkey_processed/41_38.5.csv
#   inflating: weather_turkey_processed/41_38.csv
#   inflating: weather_turkey_processed/41_39.5.csv
#   inflating: weather_turkey_processed/41_39.csv
#   inflating: weather_turkey_processed/41_40.5.csv
#   inflating: weather_turkey_processed/41_40.csv
#   inflating: weather_turkey_processed/41_41.5.csv
#   inflating: weather_turkey_processed/41_41.csv
#   inflating: weather_turkey_processed/41_42.5.csv
#   inflating: weather_turkey_processed/41_42.csv
#   inflating: weather_turkey_processed/41_43.5.csv
#   inflating: weather_turkey_processed/41_43.csv
#   inflating: weather_turkey_processed/41_44.5.csv
#   inflating: weather_turkey_processed/41_44.csv
#   inflating: weather_turkey_processed/41_45.csv
#   inflating: weather_turkey_processed/41.5_26.5.csv
#   inflating: weather_turkey_processed/41.5_26.csv
#   inflating: weather_turkey_processed/41.5_27.5.csv
#   inflating: weather_turkey_processed/41.5_27.csv
#   inflating: weather_turkey_processed/41.5_28.5.csv
#   inflating: weather_turkey_processed/41.5_28.csv
#   inflating: weather_turkey_processed/41.5_29.5.csv
#   inflating: weather_turkey_processed/41.5_29.csv
#   inflating: weather_turkey_processed/41.5_30.5.csv
#   inflating: weather_turkey_processed/41.5_30.csv
#   inflating: weather_turkey_processed/41.5_31.5.csv
#   inflating: weather_turkey_processed/41.5_31.csv
#   inflating: weather_turkey_processed/41.5_32.5.csv
#   inflating: weather_turkey_processed/41.5_32.csv
#   inflating: weather_turkey_processed/41.5_33.5.csv
#   inflating: weather_turkey_processed/41.5_33.csv
#   inflating: weather_turkey_processed/41.5_34.5.csv
#   inflating: weather_turkey_processed/41.5_34.csv
#   inflating: weather_turkey_processed/41.5_35.5.csv
#   inflating: weather_turkey_processed/41.5_35.csv
#   inflating: weather_turkey_processed/41.5_36.5.csv
#   inflating: weather_turkey_processed/41.5_36.csv
#   inflating: weather_turkey_processed/41.5_37.5.csv
#   inflating: weather_turkey_processed/41.5_37.csv
#   inflating: weather_turkey_processed/41.5_38.5.csv
#   inflating: weather_turkey_processed/41.5_38.csv
#   inflating: weather_turkey_processed/41.5_39.5.csv
#   inflating: weather_turkey_processed/41.5_39.csv
#   inflating: weather_turkey_processed/41.5_40.5.csv
#   inflating: weather_turkey_processed/41.5_40.csv
#   inflating: weather_turkey_processed/41.5_41.5.csv
#   inflating: weather_turkey_processed/41.5_41.csv
#   inflating: weather_turkey_processed/41.5_42.5.csv
#   inflating: weather_turkey_processed/41.5_42.csv
#   inflating: weather_turkey_processed/41.5_43.5.csv
#   inflating: weather_turkey_processed/41.5_43.csv
#   inflating: weather_turkey_processed/41.5_44.5.csv
#   inflating: weather_turkey_processed/41.5_44.csv
#   inflating: weather_turkey_processed/41.5_45.csv
#   inflating: weather_turkey_processed/42_26.5.csv
#   inflating: weather_turkey_processed/42_26.csv
#   inflating: weather_turkey_processed/42_27.5.csv
#   inflating: weather_turkey_processed/42_27.csv
#   inflating: weather_turkey_processed/42_28.5.csv
#   inflating: weather_turkey_processed/42_28.csv
#   inflating: weather_turkey_processed/42_29.5.csv
#   inflating: weather_turkey_processed/42_29.csv
#   inflating: weather_turkey_processed/42_30.5.csv
#   inflating: weather_turkey_processed/42_30.csv
#   inflating: weather_turkey_processed/42_31.5.csv
#   inflating: weather_turkey_processed/42_31.csv
#   inflating: weather_turkey_processed/42_32.5.csv
#   inflating: weather_turkey_processed/42_32.csv
#   inflating: weather_turkey_processed/42_33.5.csv
#   inflating: weather_turkey_processed/42_33.csv
#   inflating: weather_turkey_processed/42_34.5.csv
#   inflating: weather_turkey_processed/42_34.csv
#   inflating: weather_turkey_processed/42_35.5.csv
#   inflating: weather_turkey_processed/42_35.csv
#   inflating: weather_turkey_processed/42_36.5.csv
#   inflating: weather_turkey_processed/42_36.csv
#   inflating: weather_turkey_processed/42_37.5.csv
#   inflating: weather_turkey_processed/42_37.csv
#   inflating: weather_turkey_processed/42_38.5.csv
#   inflating: weather_turkey_processed/42_38.csv
#   inflating: weather_turkey_processed/42_39.5.csv
#   inflating: weather_turkey_processed/42_39.csv
#   inflating: weather_turkey_processed/42_40.5.csv
#   inflating: weather_turkey_processed/42_40.csv
#   inflating: weather_turkey_processed/42_41.5.csv
#   inflating: weather_turkey_processed/42_41.csv
#   inflating: weather_turkey_processed/42_42.5.csv
#   inflating: weather_turkey_processed/42_42.csv
#   inflating: weather_turkey_processed/42_43.csv
#   inflating: weather_turkey_processed/42_44.5.csv
#   inflating: weather_turkey_processed/42_44.csv
#   inflating: weather_turkey_processed/42_45.csv

# %%
shutil.copy("drive/My Drive/colab_datas/IE 492/UECM-15012015-20022020.csv","./")
shutil.copy("drive/My Drive/colab_datas/IE 492/RealTimeConsumption-01122014-09032020.csv","./")
shutil.copy("drive/My Drive/colab_datas/IE 492/all_data.feather","./")
# Out:
# './all_data.feather'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling
# %matplotlib inline
from tqdm import tqdm_notebook as tqdm

# %%
weather_paths=glob.glob("weather_turkey_processed/*.csv")
np.random.choice(weather_paths,10)
# Out:
# array(['weather_turkey_processed/39_35.5.csv',
#        'weather_turkey_processed/36.5_26.5.csv',
#        'weather_turkey_processed/41.5_29.csv',
#        'weather_turkey_processed/37_40.csv',
#        'weather_turkey_processed/40_27.5.csv',
#        'weather_turkey_processed/40_42.csv',
#        'weather_turkey_processed/40_26.5.csv',
#        'weather_turkey_processed/36_32.5.csv',
#        'weather_turkey_processed/37_27.csv',
#        'weather_turkey_processed/41_35.csv'], dtype='<U38')

# %%
# weather_turkey=pd.DataFrame()
# for path in tqdm(weather_paths):
#     df=pd.read_csv(path)
#     weather_turkey=pd.concat([weather_turkey,df]).reset_index(drop=True)
# weather_turkey

# %%
# weather_turkey.to_feather("drive/My Drive/colab_datas/IE 492/all_data.feather")

# %% [markdown]
# # Energy consumption

# %%
consumption_df=pd.read_csv("RealTimeConsumption-01122014-09032020.csv",encoding='latin-1')
consumption_df.columns=["Date","Hour","Consumption"]
consumption_df["Datetime"]=consumption_df["Date"]+" "+consumption_df["Hour"]
consumption_df["Consumption"]=consumption_df["Consumption"].apply(lambda x:x.replace(",","")).astype(float)
consumption_df["Datetime"]=pd.to_datetime(consumption_df["Datetime"])
consumption_df
# Out:
#              Date   Hour  Consumption            Datetime
# 0      31.12.2015  00:00     29590.88 2015-12-31 00:00:00
# 1      31.12.2015  01:00     27785.43 2015-12-31 01:00:00
# 2      31.12.2015  02:00     26516.53 2015-12-31 02:00:00
# 3      31.12.2015  03:00     26091.62 2015-12-31 03:00:00
# 4      31.12.2015  04:00     25871.54 2015-12-31 04:00:00
# ...           ...    ...          ...                 ...
# 36715  09.03.2020  19:00         0.00 2020-09-03 19:00:00
# 36716  09.03.2020  20:00         0.00 2020-09-03 20:00:00
# 36717  09.03.2020  21:00         0.00 2020-09-03 21:00:00
# 36718  09.03.2020  22:00         0.00 2020-09-03 22:00:00
# 36719  09.03.2020  23:00         0.00 2020-09-03 23:00:00
#
# [36720 rows x 4 columns]

# %%
## bruuuuuuuh
#consumption_df=pd.read_csv("UECM-15012015-20022020.csv",encoding='latin-1')
#consumption_df.columns=["Date","Hour","Consumption"]
#consumption_df["Datetime"]=consumption_df["Date"]+" "+consumption_df["Hour"]
#consumption_df["Datetime"]=pd.to_datetime(consumption_df["Datetime"])
#consumption_df.Consumption=consumption_df.Consumption.apply(lambda x: x.replace(".","").replace(",",".")).astype(float)
#consumption_df

# %%
consumption_df=consumption_df.loc[consumption_df["Datetime"]<pd.to_datetime("2020-03-04 00:00:00")]
consumption_df
# Out:
#              Date   Hour  Consumption            Datetime
# 0      31.12.2015  00:00     29590.88 2015-12-31 00:00:00
# 1      31.12.2015  01:00     27785.43 2015-12-31 01:00:00
# 2      31.12.2015  02:00     26516.53 2015-12-31 02:00:00
# 3      31.12.2015  03:00     26091.62 2015-12-31 03:00:00
# 4      31.12.2015  04:00     25871.54 2015-12-31 04:00:00
# ...           ...    ...          ...                 ...
# 36571  03.03.2020  19:00     37936.79 2020-03-03 19:00:00
# 36572  03.03.2020  20:00     37553.37 2020-03-03 20:00:00
# 36573  03.03.2020  21:00     36581.73 2020-03-03 21:00:00
# 36574  03.03.2020  22:00     35434.36 2020-03-03 22:00:00
# 36575  03.03.2020  23:00     33827.00 2020-03-03 23:00:00
#
# [36144 rows x 4 columns]

# %% [markdown]
# # Evaluation function

# %%
from sklearn.metrics import mean_squared_error,mean_squared_log_error,mean_absolute_error
eval_df=[]
def eval_function(name_,y_true, y_pred):
    print("RMSE: ",np.sqrt(mean_squared_error(y_true,y_pred)))
    print("RMSLE: ",np.sqrt(mean_squared_log_error(y_true,y_pred)))
    print("MAE: ",mean_absolute_error(y_true,y_pred))
    return name_, np.sqrt(mean_squared_error(y_true,y_pred)),np.sqrt(mean_squared_log_error(y_true,y_pred)),mean_absolute_error(y_true,y_pred)

# %% [markdown]
# # Naive Approach 2 Days

# %%
cons_lagged=consumption_df.copy()

# %%
cons_lagged["Consumption_2_lag"]=cons_lagged["Consumption"].shift(24*2)
cons_lagged=cons_lagged.dropna()
cons_lagged
# Out:
#              Date   Hour  Consumption            Datetime  Consumption_2_lag
# 48     02.01.2016  00:00     26224.60 2016-02-01 00:00:00           29590.88
# 49     02.01.2016  01:00     24708.58 2016-02-01 01:00:00           27785.43
# 50     02.01.2016  02:00     23771.58 2016-02-01 02:00:00           26516.53
# 51     02.01.2016  03:00     22921.29 2016-02-01 03:00:00           26091.62
# 52     02.01.2016  04:00     22870.89 2016-02-01 04:00:00           25871.54
# ...           ...    ...          ...                 ...                ...
# 36571  03.03.2020  19:00     37936.79 2020-03-03 19:00:00           35049.21
# 36572  03.03.2020  20:00     37553.37 2020-03-03 20:00:00           34901.84
# 36573  03.03.2020  21:00     36581.73 2020-03-03 21:00:00           34225.14
# 36574  03.03.2020  22:00     35434.36 2020-03-03 22:00:00           33257.06
# 36575  03.03.2020  23:00     33827.00 2020-03-03 23:00:00           31819.85
#
# [36096 rows x 5 columns]

# %%
eval_df.append(eval_function("naive_2",cons_lagged["Consumption"],cons_lagged["Consumption_2_lag"]))
# Out:
# RMSE:  3606.6493919355044
# RMSLE:  0.11286520561416101
# MAE:  2511.0528404809397

# %% [markdown]
# # Naive Approach 1 Week

# %%
cons_lagged=consumption_df.copy()

# %%
cons_lagged["Consumption_7_lag"]=cons_lagged["Consumption"].shift(24*7)
cons_lagged=cons_lagged.dropna()
cons_lagged
# Out:
#              Date   Hour  Consumption            Datetime  Consumption_7_lag
# 168    07.01.2016  00:00     28763.95 2016-07-01 00:00:00           29590.88
# 169    07.01.2016  01:00     27284.84 2016-07-01 01:00:00           27785.43
# 170    07.01.2016  02:00     26321.95 2016-07-01 02:00:00           26516.53
# 171    07.01.2016  03:00     25748.49 2016-07-01 03:00:00           26091.62
# 172    07.01.2016  04:00     25636.58 2016-07-01 04:00:00           25871.54
# ...           ...    ...          ...                 ...                ...
# 36571  03.03.2020  19:00     37936.79 2020-03-03 19:00:00           39283.70
# 36572  03.03.2020  20:00     37553.37 2020-03-03 20:00:00           38791.40
# 36573  03.03.2020  21:00     36581.73 2020-03-03 21:00:00           37588.86
# 36574  03.03.2020  22:00     35434.36 2020-03-03 22:00:00           36290.64
# 36575  03.03.2020  23:00     33827.00 2020-03-03 23:00:00           34580.08
#
# [35976 rows x 5 columns]

# %%
eval_df.append(eval_function("naive_7",cons_lagged["Consumption"],cons_lagged["Consumption_7_lag"]))
# Out:
# RMSE:  2771.8255600552093
# RMSLE:  0.0896548159911968
# MAE:  1567.3023635201246

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Regression with 2 days lag

# %%
cons_lagged=consumption_df.copy()

# %%
cons_lagged["Consumption_2_lag"]=cons_lagged["Consumption"].shift(24*2)
cons_lagged=cons_lagged.dropna()
cons_lagged
# Out:
#              Date   Hour  Consumption            Datetime  Consumption_2_lag
# 48     02.01.2016  00:00     26224.60 2016-02-01 00:00:00           29590.88
# 49     02.01.2016  01:00     24708.58 2016-02-01 01:00:00           27785.43
# 50     02.01.2016  02:00     23771.58 2016-02-01 02:00:00           26516.53
# 51     02.01.2016  03:00     22921.29 2016-02-01 03:00:00           26091.62
# 52     02.01.2016  04:00     22870.89 2016-02-01 04:00:00           25871.54
# ...           ...    ...          ...                 ...                ...
# 36571  03.03.2020  19:00     37936.79 2020-03-03 19:00:00           35049.21
# 36572  03.03.2020  20:00     37553.37 2020-03-03 20:00:00           34901.84
# 36573  03.03.2020  21:00     36581.73 2020-03-03 21:00:00           34225.14
# 36574  03.03.2020  22:00     35434.36 2020-03-03 22:00:00           33257.06
# 36575  03.03.2020  23:00     33827.00 2020-03-03 23:00:00           31819.85
#
# [36096 rows x 5 columns]

# %%
train_df=cons_lagged.loc[cons_lagged["Datetime"]<=pd.to_datetime("2019-03-03 23:00:00")]
valid_df=cons_lagged.loc[cons_lagged["Datetime"]>pd.to_datetime("2019-03-03 23:00:00")]

# %%
from sklearn.linear_model import LinearRegression

cons_lagged["Consumption_2_lag"]=cons_lagged["Consumption"].shift(24*2)
cons_lagged=cons_lagged.dropna()

model=LinearRegression()
model.fit(train_df["Consumption_2_lag"].values.reshape(-1, 1),train_df["Consumption"].values.reshape(-1, 1))
preds=model.predict(valid_df["Consumption_2_lag"].values.reshape(-1, 1))

# %%
eval_df.append(eval_function("LR_2",valid_df["Consumption"],preds))
# Out:
# RMSE:  3424.5456173909047
# RMSLE:  0.10564275989304554
# MAE:  2524.446218082396

# %% [markdown]
# ## Regression with 7 days lag

# %%
cons_lagged=consumption_df.copy()

# %%
cons_lagged["Consumption_7_lag"]=cons_lagged["Consumption"].shift(24*7)
cons_lagged=cons_lagged.dropna()
cons_lagged
# Out:
#              Date   Hour  Consumption            Datetime  Consumption_7_lag
# 168    07.01.2016  00:00     28763.95 2016-07-01 00:00:00           29590.88
# 169    07.01.2016  01:00     27284.84 2016-07-01 01:00:00           27785.43
# 170    07.01.2016  02:00     26321.95 2016-07-01 02:00:00           26516.53
# 171    07.01.2016  03:00     25748.49 2016-07-01 03:00:00           26091.62
# 172    07.01.2016  04:00     25636.58 2016-07-01 04:00:00           25871.54
# ...           ...    ...          ...                 ...                ...
# 36571  03.03.2020  19:00     37936.79 2020-03-03 19:00:00           39283.70
# 36572  03.03.2020  20:00     37553.37 2020-03-03 20:00:00           38791.40
# 36573  03.03.2020  21:00     36581.73 2020-03-03 21:00:00           37588.86
# 36574  03.03.2020  22:00     35434.36 2020-03-03 22:00:00           36290.64
# 36575  03.03.2020  23:00     33827.00 2020-03-03 23:00:00           34580.08
#
# [35976 rows x 5 columns]

# %%
train_df=cons_lagged.loc[cons_lagged["Datetime"]<=pd.to_datetime("2019-03-03 23:00:00")]
valid_df=cons_lagged.loc[cons_lagged["Datetime"]>pd.to_datetime("2019-03-03 23:00:00")]

# %%
from sklearn.linear_model import LinearRegression

cons_lagged["Consumption_7_lag"]=cons_lagged["Consumption"].shift(24*2)
cons_lagged=cons_lagged.dropna()

model=LinearRegression()
model.fit(train_df["Consumption_7_lag"].values.reshape(-1, 1),train_df["Consumption"].values.reshape(-1, 1))
preds=model.predict(valid_df["Consumption_7_lag"].values.reshape(-1, 1))

# %%
eval_df.append(eval_function("LR_7",valid_df["Consumption"],preds))
# Out:
# RMSE:  2880.6934692731347
# RMSLE:  0.09102130950449729
# MAE:  1834.349205329185

# %% [markdown]
# ## Regression with both 2 and 7 days

# %%
cons_lagged=consumption_df.copy()

# %%
cons_lagged["Consumption_2_lag"]=cons_lagged["Consumption"].shift(24*2)
cons_lagged["Consumption_7_lag"]=cons_lagged["Consumption"].shift(24*7)
cons_lagged=cons_lagged.dropna()
cons_lagged
# Out:
#              Date   Hour  ...  Consumption_2_lag Consumption_7_lag
# 168    07.01.2016  00:00  ...           29244.38          29590.88
# 169    07.01.2016  01:00  ...           27637.23          27785.43
# 170    07.01.2016  02:00  ...           26335.78          26516.53
# 171    07.01.2016  03:00  ...           25870.23          26091.62
# 172    07.01.2016  04:00  ...           25975.07          25871.54
# ...           ...    ...  ...                ...               ...
# 36571  03.03.2020  19:00  ...           35049.21          39283.70
# 36572  03.03.2020  20:00  ...           34901.84          38791.40
# 36573  03.03.2020  21:00  ...           34225.14          37588.86
# 36574  03.03.2020  22:00  ...           33257.06          36290.64
# 36575  03.03.2020  23:00  ...           31819.85          34580.08
#
# [35976 rows x 6 columns]

# %%
train_df=cons_lagged.loc[cons_lagged["Datetime"]<=pd.to_datetime("2019-03-03 23:00:00")]
valid_df=cons_lagged.loc[cons_lagged["Datetime"]>pd.to_datetime("2019-03-03 23:00:00")]

# %%
from sklearn.linear_model import LinearRegression
cons_lagged=cons_lagged.dropna()

model=LinearRegression()
model.fit(train_df[["Consumption_7_lag","Consumption_2_lag"]].values,train_df["Consumption"].values.reshape(-1, 1))
preds=model.predict(valid_df[["Consumption_7_lag","Consumption_2_lag"]].values)

# %%
eval_df.append(eval_function("LR_2_7",valid_df["Consumption"],preds))
# Out:
# RMSE:  2592.2263305746233
# RMSLE:  0.08182116225045082
# MAE:  1700.4782113762747

# %% [markdown]
# ## LR with dates

# %%
cons_lagged=consumption_df.copy()
cons_lagged["Consumption_2_lag"]=cons_lagged["Consumption"].shift(24*2)
cons_lagged["Consumption_7_lag"]=cons_lagged["Consumption"].shift(24*7)
cons_lagged["Hour"]=cons_lagged["Hour"].apply(lambda x:x.split(":")[0]).astype(int)
cons_lagged["Day"]=cons_lagged["Date"].apply(lambda x:x.split(".")[0]).astype(int)
cons_lagged["Month"]=cons_lagged["Date"].apply(lambda x:x.split(".")[1]).astype(int)
cons_lagged["weekday"]=pd.to_datetime(cons_lagged["Date"]).apply(lambda x: x.weekday()).astype(int)
cons_lagged=cons_lagged.dropna()
cons_lagged
# Out:
#              Date  Hour  Consumption  ... Day  Month  weekday
# 168    07.01.2016     0     28763.95  ...   7      1        4
# 169    07.01.2016     1     27284.84  ...   7      1        4
# 170    07.01.2016     2     26321.95  ...   7      1        4
# 171    07.01.2016     3     25748.49  ...   7      1        4
# 172    07.01.2016     4     25636.58  ...   7      1        4
# ...           ...   ...          ...  ...  ..    ...      ...
# 36571  03.03.2020    19     37936.79  ...   3      3        1
# 36572  03.03.2020    20     37553.37  ...   3      3        1
# 36573  03.03.2020    21     36581.73  ...   3      3        1
# 36574  03.03.2020    22     35434.36  ...   3      3        1
# 36575  03.03.2020    23     33827.00  ...   3      3        1
#
# [35976 rows x 9 columns]

# %%
train_df=cons_lagged.loc[cons_lagged["Datetime"]<=pd.to_datetime("2019-03-03 23:00:00")]
valid_df=cons_lagged.loc[cons_lagged["Datetime"]>pd.to_datetime("2019-03-03 23:00:00")]

# %%
from sklearn.linear_model import LinearRegression

cons_lagged=cons_lagged.dropna()

cols=train_df.columns.difference(["Date","Consumption","Datetime"]).values

model=LinearRegression()
model.fit(train_df[cols].values,train_df["Consumption"].values.reshape(-1, 1))
preds=model.predict(valid_df[cols].values)

# %%
eval_df.append(eval_function("LR_2_7_w_dates",valid_df["Consumption"],preds))
# Out:
# RMSE:  2522.875757223404
# RMSLE:  0.07974689639845284
# MAE:  1665.06492012629

# %% [markdown]
# ## LR Date categorical

# %%
cons_lagged=consumption_df.copy()
cons_lagged["Consumption_2_lag"]=cons_lagged["Consumption"].shift(24*2)
cons_lagged["Consumption_7_lag"]=cons_lagged["Consumption"].shift(24*7)
cons_lagged["Hour"]=cons_lagged["Hour"].apply(lambda x:x.split(":")[0]).astype(int)
cons_lagged["Day"]=cons_lagged["Date"].apply(lambda x:x.split(".")[0]).astype(int)
cons_lagged["Month"]=cons_lagged["Date"].apply(lambda x:x.split(".")[1]).astype(int)
cons_lagged["weekday"]=pd.to_datetime(cons_lagged["Date"]).apply(lambda x: x.weekday()).astype(int)
cons_lagged=cons_lagged.dropna()
cons_lagged
# Out:
#              Date  Hour  Consumption  ... Day  Month  weekday
# 168    07.01.2016     0     28763.95  ...   7      1        4
# 169    07.01.2016     1     27284.84  ...   7      1        4
# 170    07.01.2016     2     26321.95  ...   7      1        4
# 171    07.01.2016     3     25748.49  ...   7      1        4
# 172    07.01.2016     4     25636.58  ...   7      1        4
# ...           ...   ...          ...  ...  ..    ...      ...
# 36571  03.03.2020    19     37936.79  ...   3      3        1
# 36572  03.03.2020    20     37553.37  ...   3      3        1
# 36573  03.03.2020    21     36581.73  ...   3      3        1
# 36574  03.03.2020    22     35434.36  ...   3      3        1
# 36575  03.03.2020    23     33827.00  ...   3      3        1
#
# [35976 rows x 9 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import hstack

cat_features=["Hour","Day","Month","weekday"]
linear_enc=OneHotEncoder()
one_hot_encoded=linear_enc.fit_transform(cons_lagged[cat_features]).toarray()
normal_feats=cons_lagged.columns.difference(cat_features).tolist()
cons_lagged=np.hstack([cons_lagged[normal_feats],one_hot_encoded])
cons_lagged=pd.DataFrame(cons_lagged,columns=normal_feats+np.concatenate([[cat_features[i]+"_"+str(j) for j in cats_]for i,cats_ in enumerate(linear_enc.categories_)]).tolist())

# %%
train_df=cons_lagged.loc[cons_lagged["Datetime"]<=pd.to_datetime("2019-03-03 23:00:00")]
valid_df=cons_lagged.loc[cons_lagged["Datetime"]>pd.to_datetime("2019-03-03 23:00:00")]

# %%
from sklearn.linear_model import LinearRegression

cons_lagged=cons_lagged.dropna()

cols=train_df.columns.difference(["Date","Consumption","Datetime"]).values

model=LinearRegression()
model.fit(train_df[cols].values,train_df["Consumption"].values.reshape(-1, 1))
preds=model.predict(valid_df[cols].values)

# %%
eval_df.append(eval_function("LR_2_7_w_dates",valid_df["Consumption"],preds))
# Out:
# RMSE:  2411.7410279998844
# RMSLE:  0.0762868233130247
# MAE:  1592.3783633510911

# %% [markdown]
# ## LR Date cyclical

# %%
cons_lagged=consumption_df.copy()
cons_lagged["Consumption_2_lag"]=cons_lagged["Consumption"].shift(24*2)
cons_lagged["Consumption_7_lag"]=cons_lagged["Consumption"].shift(24*7)
cons_lagged["Hour"]=cons_lagged["Hour"].apply(lambda x:x.split(":")[0]).astype(int)
cons_lagged["Day"]=cons_lagged["Date"].apply(lambda x:x.split(".")[0]).astype(int)
cons_lagged["Month"]=cons_lagged["Date"].apply(lambda x:x.split(".")[1]).astype(int)
cons_lagged["weekday"]=pd.to_datetime(cons_lagged["Date"]).apply(lambda x: x.weekday()).astype(int)
cons_lagged=cons_lagged.dropna()
cons_lagged
# Out:
#              Date  Hour  Consumption  ... Day  Month  weekday
# 168    07.01.2016     0     28763.95  ...   7      1        4
# 169    07.01.2016     1     27284.84  ...   7      1        4
# 170    07.01.2016     2     26321.95  ...   7      1        4
# 171    07.01.2016     3     25748.49  ...   7      1        4
# 172    07.01.2016     4     25636.58  ...   7      1        4
# ...           ...   ...          ...  ...  ..    ...      ...
# 36571  03.03.2020    19     37936.79  ...   3      3        1
# 36572  03.03.2020    20     37553.37  ...   3      3        1
# 36573  03.03.2020    21     36581.73  ...   3      3        1
# 36574  03.03.2020    22     35434.36  ...   3      3        1
# 36575  03.03.2020    23     33827.00  ...   3      3        1
#
# [35976 rows x 9 columns]

# %%
cons_lagged['Hour_sin'] = np.sin(2 * np.pi * cons_lagged['Hour']/23.0)
cons_lagged['Hour_cos'] = np.cos(2 * np.pi * cons_lagged['Hour']/23.0)

cons_lagged['Day_sin'] = np.sin(2 * np.pi * cons_lagged['Day']/31.0)
cons_lagged['Day_cos'] = np.cos(2 * np.pi * cons_lagged['Day']/31.0)

cons_lagged['Month_sin'] = np.sin(2 * np.pi * cons_lagged['Month']/12.0)
cons_lagged['Month_cos'] = np.cos(2 * np.pi * cons_lagged['Month']/12.0)

cons_lagged['weekday_sin'] = np.sin(2 * np.pi * cons_lagged['weekday']/6.0)
cons_lagged['weekday_cos'] = np.cos(2 * np.pi * cons_lagged['weekday']/6.0)

del cons_lagged['Hour'],cons_lagged['Day'],cons_lagged['Month'],cons_lagged['weekday']

# %%
train_df=cons_lagged.loc[cons_lagged["Datetime"]<=pd.to_datetime("2019-03-03 23:00:00")]
valid_df=cons_lagged.loc[cons_lagged["Datetime"]>pd.to_datetime("2019-03-03 23:00:00")]

# %%
from sklearn.linear_model import LinearRegression

cons_lagged=cons_lagged.dropna()

cols=train_df.columns.difference(["Date","Consumption","Datetime"]).values

model=LinearRegression()
model.fit(train_df[cols].values,train_df["Consumption"].values.reshape(-1, 1))
preds=model.predict(valid_df[cols].values)

# %%
eval_df.append(eval_function("LR_2_7_w_dates",valid_df["Consumption"],preds))
# Out:
# RMSE:  2546.609637825625
# RMSLE:  0.08020123457490627
# MAE:  1689.0600541092615

# %%
cons_lagged
# Out:
#              Date  Hour  Consumption  ...     Month_cos  weekday_sin  weekday_cos
# 168    07.01.2016     0     28763.95  ...  8.660254e-01    -0.866025         -0.5
# 169    07.01.2016     1     27284.84  ...  8.660254e-01    -0.866025         -0.5
# 170    07.01.2016     2     26321.95  ...  8.660254e-01    -0.866025         -0.5
# 171    07.01.2016     3     25748.49  ...  8.660254e-01    -0.866025         -0.5
# 172    07.01.2016     4     25636.58  ...  8.660254e-01    -0.866025         -0.5
# ...           ...   ...          ...  ...           ...          ...          ...
# 36571  03.03.2020    19     37936.79  ...  6.123234e-17     0.866025          0.5
# 36572  03.03.2020    20     37553.37  ...  6.123234e-17     0.866025          0.5
# 36573  03.03.2020    21     36581.73  ...  6.123234e-17     0.866025          0.5
# 36574  03.03.2020    22     35434.36  ...  6.123234e-17     0.866025          0.5
# 36575  03.03.2020    23     33827.00  ...  6.123234e-17     0.866025          0.5
#
# [35976 rows x 17 columns]

# %%
residuals=model.predict(train_df[cols].values,train_df["Consumption"].)

# %% [markdown]
# ## Datelar promosyon tipleri koyulacak, sonradan lineer regresyon direkt vermeme gerek yok

# %%
special_days_path="drive/My Drive/colab_datas/IE 492/ozel_gunler/*"
special_day_df=pd.DataFrame()
exception=[]
for i in tqdm(glob.glob(special_days_path)):  
    a=pd.read_csv(i)
    try:
        a["special_day"]=np.full(len(a),a.columns[0])
        a.columns=["date","special_day"]
        special_day_df=pd.concat([special_day_df, a])
    except ValueError:
        exception.append(i)
        pass
special_day_df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(IntProgress(value=0, max=41), HTML(value='')))
#           date   special_day
# 1   2015-10-01     elections
# 2   2015-07-07     elections
# 3   2017-04-16     elections
# 4   2018-06-24     elections
# 5   2019-03-31     elections
# ..         ...           ...
# 6   2015-08-30  zaferbayrami
# 7   2016-08-30  zaferbayrami
# 8   2017-08-30  zaferbayrami
# 9   2018-08-30  zaferbayrami
# 10  2019-08-30  zaferbayrami
#
# [4235 rows x 2 columns]

# %%
special_day_df["is"]=np.ones(len(special_day_df))
special_day_df=pd.pivot_table(special_day_df,index="date",columns="special_day").fillna(0).astype(int)
special_day_df.columns=['_'.join(i) for i in special_day_df.columns]
special_day_df=special_day_df.reset_index()
special_day_df
# Out:
#             date  is_annelergunu  ...  is_yilbasioncesi  is_zaferbayrami
# 0     2010-01-01               0  ...                 0                0
# 1     2010-01-22               0  ...                 0                0
# 2     2010-01-23               0  ...                 0                0
# 3     2010-01-24               0  ...                 0                0
# 4     2010-01-25               0  ...                 0                0
# ...          ...             ...  ...               ...              ...
# 2410  2019-12-27               0  ...                 0                0
# 2411  2019-12-28               0  ...                 0                0
# 2412  2019-12-29               0  ...                 0                0
# 2413  2019-12-30               0  ...                 0                0
# 2414  2019-12-31               0  ...                 0                0
#
# [2415 rows x 41 columns]

# %% [markdown]
# ## LR Date categorical and spec days

# %%
cons_lagged=consumption_df.copy()
cons_lagged["Consumption_2_lag"]=cons_lagged["Consumption"].shift(24*2)
cons_lagged["Consumption_7_lag"]=cons_lagged["Consumption"].shift(24*7)
cons_lagged["Hour"]=cons_lagged["Hour"].apply(lambda x:x.split(":")[0]).astype(int)
cons_lagged["Day"]=cons_lagged["Date"].apply(lambda x:x.split(".")[0]).astype(int)
cons_lagged["Month"]=cons_lagged["Date"].apply(lambda x:x.split(".")[1]).astype(int)
cons_lagged["weekday"]=pd.to_datetime(cons_lagged["Date"]).apply(lambda x: x.weekday()).astype(int)
cons_lagged=cons_lagged.dropna()
cons_lagged
# Out:
#              Date  Hour  Consumption  ... Day  Month  weekday
# 168    07.01.2016     0     28763.95  ...   7      1        4
# 169    07.01.2016     1     27284.84  ...   7      1        4
# 170    07.01.2016     2     26321.95  ...   7      1        4
# 171    07.01.2016     3     25748.49  ...   7      1        4
# 172    07.01.2016     4     25636.58  ...   7      1        4
# ...           ...   ...          ...  ...  ..    ...      ...
# 36571  03.03.2020    19     37936.79  ...   3      3        1
# 36572  03.03.2020    20     37553.37  ...   3      3        1
# 36573  03.03.2020    21     36581.73  ...   3      3        1
# 36574  03.03.2020    22     35434.36  ...   3      3        1
# 36575  03.03.2020    23     33827.00  ...   3      3        1
#
# [35976 rows x 9 columns]

# %%
special_day_df["date"]=pd.to_datetime(special_day_df["date"])
special_day_df["date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
cons_lagged=pd.merge(cons_lagged,special_day_df,left_on="Datetime",right_on="date",how="left").drop(columns="date").fillna(0)
cons_lagged
# Out:
#              Date  Hour  ...  is_yilbasioncesi is_zaferbayrami
# 0      07.01.2016     0  ...               0.0             0.0
# 1      07.01.2016     1  ...               0.0             0.0
# 2      07.01.2016     2  ...               0.0             0.0
# 3      07.01.2016     3  ...               0.0             0.0
# 4      07.01.2016     4  ...               0.0             0.0
# ...           ...   ...  ...               ...             ...
# 35971  03.03.2020    19  ...               0.0             0.0
# 35972  03.03.2020    20  ...               0.0             0.0
# 35973  03.03.2020    21  ...               0.0             0.0
# 35974  03.03.2020    22  ...               0.0             0.0
# 35975  03.03.2020    23  ...               0.0             0.0
#
# [35976 rows x 49 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import hstack

cat_features=["Hour","Day","Month","weekday"]
linear_enc=OneHotEncoder()
one_hot_encoded=linear_enc.fit_transform(cons_lagged[cat_features]).toarray()
normal_feats=cons_lagged.columns.difference(cat_features).tolist()
cons_lagged=np.hstack([cons_lagged[normal_feats],one_hot_encoded])
cons_lagged=pd.DataFrame(cons_lagged,columns=normal_feats+np.concatenate([[cat_features[i]+"_"+str(j) for j in cats_]for i,cats_ in enumerate(linear_enc.categories_)]).tolist())

# %%
cons_lagged
# Out:
#       Consumption Consumption_2_lag  ... weekday_5 weekday_6
# 0           28764           29244.4  ...         0         0
# 1         27284.8           27637.2  ...         0         0
# 2           26322           26335.8  ...         0         0
# 3         25748.5           25870.2  ...         0         0
# 4         25636.6           25975.1  ...         0         0
# ...           ...               ...  ...       ...       ...
# 35971     37936.8           35049.2  ...         0         0
# 35972     37553.4           34901.8  ...         0         0
# 35973     36581.7           34225.1  ...         0         0
# 35974     35434.4           33257.1  ...         0         0
# 35975       33827           31819.8  ...         0         0
#
# [35976 rows x 119 columns]

# %%
train_df=cons_lagged.loc[cons_lagged["Datetime"]<=pd.to_datetime("2019-03-03 23:00:00")]
valid_df=cons_lagged.loc[cons_lagged["Datetime"]>pd.to_datetime("2019-03-03 23:00:00")]

# %%
sp_days_index=[i for i,col in enumerate(train_df[cols].columns) if col.startswith("is_")]

# %%
from sklearn.linear_model import LinearRegression

cons_lagged=cons_lagged.dropna()

cols=train_df.columns.difference(["Date","Consumption","Datetime"]).values

model=LinearRegression()
model.fit(train_df[cols].values,train_df["Consumption"].values.reshape(-1, 1))
preds=model.predict(valid_df[cols].values)

# %%
eval_df.append(eval_function("LR_2_7_w_dates",valid_df["Consumption"],preds))
# Out:
# RMSE:  2412.74622328101
# RMSLE:  0.07634896064818732
# MAE:  1592.7063299341169

# %%
sum(model.coef_[0][sp_days_index].tolist())
# Out:
# 9285.206128964073
